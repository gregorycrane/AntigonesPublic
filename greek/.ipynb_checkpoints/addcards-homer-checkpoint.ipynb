# %%
card_alignment = {
    "ACHILLES' wrath, to Greece the direful spring": "1.1",
    "The trembling priest along the shore return'd,": "1.33",
    "He said, and sat: when Chalcas thus replied,": "1.68",
    "To whom Pelides. 'From thy inmost soul": "1.92",
    "Then thus the king. 'Shall I my prize resign": "1.130",
    "To this the king: 'Fly, mighty warrior! fly,": "1.172",
    "Forbear!' (the progeny of Jove replies)": "1.206",
    "He spoke; and furious hurl'd against the ground": "1.245",
    "Here on the monarch's speech Achilles broke,": "1.285",
    "The army thus in sacred rites engaged,": "1.312",
    "Patroclus now th' unwilling beauty brought;": "1.345",
    "Myself the first th' assembled chiefs incline" : "1.386",
    "The goddess spoke: the rolling waves unclose" : "1.428",
    "And now the Greeks their hecatomb prepare": "1.458",
    "Twelve days were past, and now the dawning light": "1.493",
    "The shining synod of th' immortals wait": "1.531",
    "The Thunderer spoke, nor durst the queen reply;": "1.568",
    "Now pleasing sleep had seal'd each mortal eye,": "2.1",
    "The phantom said; then vanish'd from his sight,": "2.35",
    "He spoke, and sat; when Nestor rising said": "2.76",
    "On this bright sceptre now the king reclin'd,": "2.109",
    "E'en then the Greeks had left the hostile plain" : "2.155",
    "Each prince of name, or chief in arms approv": "2.188",
    "Thus with injurious taunts attack'd the throne" : "2.224",
    "He said, and cowering as the dastard bends,": "2.265",
    "'What pass'd at Aulis, Greece can": "2.301",
    "Then Nestor thus: 'These vain debates forbear:": "2.336",
    "To him the king: 'How much thy years excel": "2.369",
    "Thus pray'd the chief: his unavailing prayer": "2.419",
    "Not less their number than th' embodied cranes,": "2.459",
    "To these succeed Asplendon's martial train": "2.511",
    "Full fifty more from Athens stem the main": "2.546",
    "His brother follows, and to vengeance warms": "2.581",
    "Those, where fair Elis and Buprasium join;": "2.615",
    "Tlepolemus, the son of Hercules": "2.653",
    "To these the youth of Phylacè succeed,": "2.695",
    "The bold Ormenian and Asterian bands": "2.734",
    "Last under Prothous the Magnesians stood,": "2.760",
    "Now, like a deluge, covering all around,": "2.780",
    "Divine Æneas brings the Dardan race": "2.819",
    "There, mighty Chromis led the Mysian train": "2.858",

# book 3
    "THUS by their leader's care each martial band": "3.1",
    "As godlike Hector sees the prince retreat,": "3.38",
    "He said. The challenge Hector heard with joy,": "3.76",
    "The nations hear, with rising hopes possess": "3.111",
    "There sat the seniors of the Trojan race;": "3.146",
    "This said, once more he view'd the warrior-train": "3.191",
    "The king then ask'd, (as yet the camp he view'd,)": "3.225",
    "Next from the car, descending on the plain,": "3.264",
    "Thus either host their imprecations join'd": "3.302",
    "Now round the lists th' admiring armies stand,": "3.340",
    "Meantime the brightest of the female kind,": "3.383",
    "Arriv'd, and enter'd at the palace gate,": "3.421",
    "AND now Olympus' shining gates unfold;": "4.1",
    "At this the goddess roll'd her radiant eyes,": "4.50",
    "They said, while Pallas through the Trojan throng": "4.85",
    "But thee, Atrides! in that dangerous hour": "4.127",
    "He said: a leader's and a brother's fears": "4.183",
    "Nor had you seen the king of men appear": "4.223",
    "To whom the Cretan thus his speech address'd": "4.265",
    "So spoke the master of the martial art,": "4.310",
    "'Take back th' unjust reproach! Behold we stand": "4.350",
    "Thus with new vigour he the brave inspires;": "4.369",
    "No words the godlike Diomed return'd": "4.401",
    "Now shield with shield, with helmet helmet clos'd": "4.446",
    "Thus, pierc'd by Ajax, Simoïsius lies": "4.488",
    "Then great Diores fell, by doom divine;": "4.517",
    

    "BUT Pallas now Tydides' soul inspires,": "5.1",
    "Thy fate was next, O Phæstus! doom'd to feel": "5.43",
    "Thus toil'd the chiefs, in different parts engag'd,": "5.84",
    "Thus pray'd Tydides, and Minerva heard,": "5.121",
    "Two sons of Priam in one chariot ride,": "5.159",
    "But, vain with youth, and yet to thrift inclin'd,": "5.201",
    "And now both heroes mount the glittering car;": "5.239",
    "He said, then shook the ponderous lance, and flung;": "5.280",
    "Safe through the rushing horse, and feather'd flight": "5.318",
    "Stern Mars attentive hears the queen complain": "5.363",
    "This said, she wip'd from Venus' wounded palm": "5.416",
    "The god of battles issues on the plain,": "5.460",
    "Stung to the heart the generous Hector hears,": "5.493",
    "These words he seconds with his flying lance,": "5.533",
    "First Pylæmenes, great in battle, bled,": "5.576",
    "While thus they strive, Tlepolemus the great,": "5.627",
    "The Greeks with slain Tlepolemus retir'd;": "5.668",
    "The carnage Juno from the skies survey'd,": "5.711",
    "To whom assenting, thus the Thunderer said:": "5.764",
    "Her speech new fury to their hearts convey'd;": "5.792",
    "She said, and to the steeds approaching near,": "5.835",
    "As vapours blown by Auster's sultry breath,": "5.864",
    "Then gave to Pæon's care the bleeding god.": "5.899",
# book 6
    "Now heaven forsakes the fight; th' immortals yield": "6.1",
    "Unbless'd Adrastus next at mercy lies": "6.37",
    "The monarch spoke; the words, with warmth address'd,": "6.72",
    "Hector obedient heard; and, with a bound,": "6.116",
    "'Who o'er the sons of men in beauty shin'd": "6.156",
    "At length the monarch with repentant grief": "6.191",
    "Thus having said, the gallant chiefs alight,": "6.232",
    "'Far hence be Bacchus' gifts;'": "6.263",
    "Soon as to Ilion's topmost tower they come,": "6.297",
    "Brother, 'tis just,' (replied the beauteous youth,)": "6.332",
    "He said, and pass'd with sad presaging heart": "6.369",
    "'No parent now remains, my griefs": "6.414",
    "Thus having spoke, th' illustrious chief of Troy": "6.466",
    "But now, no longer deaf to honour's call,": "6.503",


    "So spoke the guardian of the Trojan state,": "7.1",
    "At this agreed, the heavenly powers withdrew;": "7.43",
    "This fierce defiance Greece astonish'd heard,": "7.92",
    '<l n="7.159">\'Oh! would to all th' : "7.132",
    "The lots produc'd, each hero signs his own;": "7.175",
    "Now Ajax brac'd his dazzling armour on;": "7.206",
    "He said, and, rising high above the field,": "7.244",
    "To whom great Ajax his high soul express'd:": "7.283",
    "A steer for sacrifice the king design'd,": "7.313",
    "The senior spoke, and sat. To whom replied": "7.354",
    "The Greeks give ear, but none the silence broke;": "7.398",
    "So toil'd the Greeks: ": "7.442",


    "AURORA now, fair daughter of the dawn,": "8.1",
    "Then call'd his coursers, and his chariot took;": "8.41",
    "Nor great Idomeneus that sight could bear,": "8.78",
    "Thus said the chief; and Nestor, skill'd in war,": "8.112",
    "To whom Gerenian<ref n=": "8.151",
    "That heard, deep anguish stung Saturnia's soul;": "8.198",
    "Thus pray'd the king, and heaven's great father heard": "8.245",
    "To this the chief: 'With praise the rest inspire,": "8.292",
    "Troy yet found grace before th' Olympian sire;": "8.335",
    "She ceas'd, and Juno rein'd the steeds with care,": "8.381",
    "Then, mounting on the pinions of the wind,": "8.425",
    "The goddess thus: and thus the god replies,": "8.469",
    "'Not unmolested let the wretches gain": "8.512",
    "The troops exulting sat in order round,": "8.553",


    "THUS joyful Troy maintain'd the watch of night;": "9.1",
    "He said; deep silence held the Grecian band;": "9.50",
    "The king of men, on public counsels bent,": "9.89",
    "To whom the king: 'With justice hast thou shewn": "9.114",
    "The monarch thus: the reverend Nestor then:": "9.162",
    "He said: Patroclus, o'er the blazing": "9.205",
    "'Heavens! how my country's woes distract my mind": "9.244",
    "'Yet more-three daughters in his court": "9.286",
    "'I sack'd twelve ample cities on the main,": "9.328",
    
    "'Tell him, all terms, all commerce I decline,": "9.374",
    "Go then, to Greece report our fix'd design:": "9.417",
    "My sire with curses loads my hated head,": "9.453",
    "'The tender labours, the compliant cares;": "9.492",
    "'In vengeance of neglected sacrifice;": "9.538",
    "His suppliant father, aged Œneus, came;": "9.581",
    "He ceas'd: then order'd for the sage's bed": "9.620",
    "And now th' elected chiefs, whom Greece had sent,": "9.669",


    "ALL night the chiefs before their vessels lay,": "10.1",
    "To whom the king: 'In such distress we stand,": "10.42",
    "'O son of Neleus!' (thus the king rejoin'd)": "10.86",
    "'Then none' (said Nestor) 'shall his rule withstand,": "10.128",
    "'My friend,' (he answer'd,) 'generous is thy care,": "10.168",
    "Fear held them mute: alone, untaught to fear,": "10.218",
    "Thus having spoke, with generous ardour press'd,": "10.254",
    "The heroes pray'd, and Pallas, from the skies,": "10.295",
    "Thus Hector swore: the gods were call'd in vain;": "10.332",
    "He said, and high in air the weapon cast,": "10.372",
    "Ulysses thus, and thus Eumedes' son:": "10.412",
    "Sternly he spoke, and, as the wretch prepar'd": "10.454",
    "Doubtful he stood, or with his reeking blade": "10.503",
    "Scarce had he spoke, when lo! the chiefs appear,": "10.540",


    "THE saffron morn, with early blushes spread,": "11.1",
    "Close to the limits of the trench and mound,": "11.47",
    "Thus while the morning beams increasing bright": "11.84",
    "Amidst the tumult of the routed train,": "11.122",
    "Perhaps great Hector then had found his fate,": "11.163",
    "She said, and vanish'd: Hector with a bound,": "11.210",
    "Coön, Antenor's eldest hope, was nigh:": "11.248",
    "With words like these the fiery chief alarms": "11.291",
    "Great Jove from Ide with slaughter fills his sight,": "11.336",
    "Him, while he triumph'd, Paris ey'd from far,": "11.368",
    "Such thoughts revolving in his careful breast,": "11.411",
    "Then, raging with intolerable smart,": "11.456",
    "Victorious Ajax plies the routed crew;": "11.489",
    "Thus having spoke, the driver's lash resounds;": "11.531",
    "But bold Eurypylus his aid imparts,": "11.575",
    "The hero said. His friend obey'd with haste;": "11.616",
    "'Can then the sons of Greece' (the sage rejoin'd)": "11.655",
    "'Oppress'd, we arm'd; and now, this conquest gain'd,": "11.696",
    "'Bright scenes of arms, and works of war appear;": "11.737",
    "'Social we sit, and share the genial rites.": "11.780",
    "Eurypylus replies: 'No more, my friend,": "11.822",


    "While thus the hero's pious cares attend": "12.1",
    "But this the gods in later times perform;": "12.34",
    "This counsel pleas'd: the godlike Hector sprung": "12.80",
    "While every Trojan thus, and every aid,": "12.108",
    "To save their fleet, the last efforts they try,": "12.153",
    "Meantime, the bravest of the Trojan crew,": "12.195",
    "To him then Hector with disdain return'd:": "12.230",
    "Their ardour kindles all the Grecian powers;": "12.277",
    "He said; his words the listening chief inspire": "12.329",
    "Straight to the fort great Ajax turn'd his care,": "12.364",
    "At once bold Teucer draws the twanging bow,": "12.400",
    "They hear, they run, and, gathering at his call,": "12.442",


    "WHEN now the Thunderer on the sea-beat coast": "13.1",
    "Deep in the liquid regions lies a cave,": "13.32",
    "Then with his sceptre that the deep controls,": "13.59",
    "Full of the god that urg'd their burning breast,": "13.81",
    "These words the Grecians' fainting hearts inspire,": "13.125",
    "He said, and rous'd the soul in every breast;": "13.155",
    "Between the leaders of th' Athenian line,": "13.195",
    "Thus he; and thus the god whose force can make": "13.231",
    "'Nor vain' (said Merion) 'are our martial toils;": "13.266",
    "Swift as the word bold Merion snatch'd a spear,": "13.295",
    "He said; and Merion to th' appointed place,": "13.328",
    "Dreadful in arms, and grown in combat grey,": "13.361",
    "Stabb'd at the sight, Deïphobus drew nigh,": "13.402",
    "Nor yet from fight Idomeneus withdraws;": "13.424",
    "The Trojan heard; uncertain, or to meet": "13.455",
    "He spoke, and all as with one soul obey'd;": "13.487",
    "Now, where in dust the breathless hero lay,": "13.526",
    "The son of Asius, Adamas, drew near,": "13.560",
    "Behold! Pisander, urg'd by Fate's decree,": "13.601",
    "This said, he seiz'd (while yet the carcass heav'd)": "13.640",
    "Nor knew great Hector how his legions yield,": "13.673",
    "Now had the Greeks eternal fame acquir'd,": "13.723",
    "This said, the towering chief prepares to go,": "13.754",
    "These words the hero's angry mind assuage:": "13.788",
    "As thus he spoke, behold, in open view,": "13.821",

    "BUT nor the genial feast, nor flowing bowl,": "14.1",
    "Him, in his march, the wounded princes meet,": "14.27",
    "To him the monarch:<ref n=": "14.64",
    "'Thy just reproofs' (Atrides calm replies,)": "14.103",
    "Meantime Saturnia from Olympus' brow,": "14.154",
    "'Let heaven's dread empress' (Cytherea said)": "14.193",
    "'Imperial dame,' (the balmy power replies,)": "14.242",
    "'Swear then' (he said) 'by those tremendous floods,": "14.270",
    "'For that,' (said Jove) 'suffice another day;": "14.312",
    "At length with love and sleep's soft power oppress'd,": "14.352",
    "The troops assent; their martial arms they change,": "14.378",
    "The first bold javelin, urg'd by Hector's force,": "14.402",
    "Soon as the Greeks the chief's retreat beheld,": "14.440",
    "He spake, and smil'd severe, for well he knew": "14.475",
    "Dreadful he spoke, then toss'd the head on high;": "14.506",

    "Now in swift flight they pass the trench profound,": "15.1",
    "The Thunderer spoke: imperial Juno mourn'd,": "15.34",
    "'Think'st thou with me? fair empress of the skies!'": "15.47",
    "The trembling queen (th' almighty order given)": "15.78",
    "To whom the white-arm'd goddess thus replies:": "15.92",
    "Stern Mars, with anguish for his slaughter'd son,": "15.113",
    "And now had Jove, by bold rebellion driven,": "15.119",
    "This menace fix'd the warrior to his throne;": "15.142",
    "She said, and sat. The god that gilds the day,": "15.149",
    "Th' Almighty spoke; the goddess wing'd her flight": "15.168",
    "'What means the haughty sovereign of the skies?'": "15.184",
    "'And must I then,' (said she,) 'O sire of floods!": "15.200",
    "'Great is the profit,' (thus the god rejoin'd,)": "15.205",
    "Thus speaking, furious from the field he strode,": "15.218",
    "The lord of thunders from his lofty height": "15.220",
    "Not half so swift the sailing falcon flies,": "15.236",
    "'Why sits great Hector from the field so far,": "15.244",
    "The fainting hero, as the vision bright": "15.246",
    "To him Apollo: 'Be no more dismay'd;": "15.253",
    "As when the pamper'd steed, with reins unbound,": "15.263",
    "They fly: at once the chasers and the prey": "15.281",
    "The warrior spoke, the listening Greeks obey,": "15.300",
    "The Greeks expect the shock; the clamours rise": "15.312",
    "Heaps fall on heaps: the slaughter Hector leads;": "15.328",
    "The Greeks dismay'd, confus'd, disperse or fall,": "15.343",
    "Furious he said; the smarting scourge resounds;": "15.352",
    "While thus the thunder of the battle rag'd,": "15.367",
    "Presumptuous Troy mistook th' accepting sign,": "15.379",
    "Still in the tent Patroclus sat, to tend": "15.390",
    "He spoke; and, speaking, swifter than the wind": "15.405",
    "This said, his eager javelin sought the foe:": "15.429",
    "Impatient Teucer, hastening to his aid,": "15.442",
    "Then Teucer laid his faithless bow aside": "15.478",
    "This rous'd the soul in every Trojan breast.": "15.500",
    "The listening Grecians feel their leader's flame,": "15.514",
    "Hector (this said) rush'd forward on the foes:": "15.559",
    "Now on the fleet the tides of Trojans drove,": "15.592",
    "Chas'd from the foremost line, the Grecian train": "15.653",
    "So when a horseman from the watery mead": "15.685",
    "Thou would'st have thought, so furious was their fire,": "15.696",
    "He spoke. The warriors, at his fierce command,": "15.726",


    "So warr'd both armies on th' ensanguin'd shore,": "16.1",
    "'Thus, blind to fate! with supplicating breath,": "16.46",
    "'No longer flames the lance of Tydeus' son" : "16.74",
    "Such conference held the chiefs: while, on the strand,": "16.101",
    "Say, Muses, thron'd above the starry frame,": "16.112",
    "First march'd Menestheus, of celestial birth,": "16.155",
    "Soon as Achilles with superior care": "16.200",
    "Great Jove consents to half the chief's request": "16.249",
    "Then first thy spear, divine Patroclus! flew,": "16.284",
    "In equal arms two sons of Nestor stand,": "16.306",
    "As when the flocks neglected by the swain": "16.351",
    "Patroclus shakes his lance; but fate denies" : "16.394",
    "Then thus the goddess with the radiant eyes:": "16.439",
    "And first Sarpedon whirl'd his mighty lance": "16.477",
    "All-impotent of aid, transfix'd with grief,": "16.508",
    "He spoke: each leader in his grief partook;": "16.548",
    "Now Greece gives way, and great Epigeus falls;": "16.569",
    "'O valiant leader of the Dardan host!": "16.619",
    "Then, nor before, the hardy Lycians fled": "16.659",
    "Now Troy had stoop'd beneath his matchless power,": "16.698",
    "So spoke th' inspiring god: then took his flight,": "16.726",
    "Then rushing sudden on his prostrate prize,": "16.750",
    "Now, flaming from the zenith, Sol had driven": "16.777",
    "Stern Hector, as the bleeding chief he views,": "16.818",


    "ON the cold earth divine Patroclus spread,": "17.1",
    "Swift as the word the missile lance he flings,": "17.44",
    "Thus having spoke, Apollo wing'd his flight,": "17.82",
    "The time allow'd: Troy thicken'd on the shore;": "17.106",
    "But Glaucus, leader of the Lycian aids,": "17.140",
    "'Be men (my friends) in action as in name,": "17.185",
    "Then with his sable brow he gave the nod,": "17.209",
    "The warrior rais'd his voice, and wide around": "17.246",
    "The first attack the Grecians scarce sustain,": "17.274",
    "And now had Troy, by Greece compell'd to yield,": "17.319",
    "Fierce as conflicting fires, the combat burns,": "17.366",
    "Such Jove to honour the great dead ordain": "17.400",
    "Then clash their sounding arms; the clangors rise,": "17.423",
    "He said; and breathing in th' immortal horse": "17.456",
    "The son of Venus to the counsel yields:": "17.491",
    "He spoke, and high the sounding javelin flung,": "17.516",
    "And now Minerva, from the realms of air,": "17.543",
    "Pleas'd to be first of all the powers address'd,": "17.567",
    "Then trembled Greece: the flight Peneleus led;": "17.597",
    "Nor Ajax less the will of heaven descried,": "17.626",
    "So turns the lion from the nightly fold,": "17.656",
    "The youthful warrior heard with silent woe,": "17.694",
    "While thus aloft the hero's corse they bear,": "17.735",


    "THUS like the rage of fire the combat burns,": "18.1",
    "A sudden horror shot through all the chief,": "18.22",
    "'Hear me, and judge, ye sisters of the main!": "18.52",
    "She said, and left the caverns of the main.": "18.65",
    "He, deeply groaning, 'To this cureless grief": "18.78",
    "‘Let Hector die,": "18.97",
    "‘My son,’ (cærulean Thetis made reply": "18.127",
    "And now the Greeks, from furious Hector's force,": "18.148",
    "‘Who sends thee, goddess! from th": "18.181",
    "She spoke, and past in air. The hero rose:": "18.202",
    "As the loud trumpet's brazen mouth from far": "18.219",
    "The frighted Trojans (panting from the war,": "18.243",
    "‘Return?’ (said Hector,": "18.284",
    "‘In what vain promise, gods! did I engage": "18.324",
    "‘What words are these?’ (th' imperial": "18.360",
    "High on a throne, with stars of silver graced,": "18.388",
    "To whom the mournful mother thus replies:": "18.428",
    "To her the artist-god:": "18.462",
    "Two cities radiant on the shield appear,": "18.490",
    "In arms the glittering squadron rising round,": "18.527",
    "Next ripe, in yellow gold, a vineyard shines,": "18.561",
    "A figured dance succeeds: such once was seen": "18.590",


    "SOON as Aurora heaved her orient head": "19.1",
    "Then drops the radiant burden on the ground;": "19.12",
    "'Goddess!' (he cried,) 'these glorious arms that shine": "19.21",
    "'That unavailing care be laid aside,'": "19.28",
    "Then in the nostrils of the slain she pour'd": "19.37",
    "Achilles to the strand obedient went;": "19.40",
    "'Oh monarch! better far had been the fate": "19.56",
    "He said; his finish'd wrath with loud acclaim": "19.74",
    "‘The joyful goddess, from Olympus' height,": "19.114",
    "The great in councils, Ithacus the wise": "19.154",
    "‘For this’ (the stern Æacides replies)": "19.184",
    "‘O first of Greeks!’ (Ulysses thus rejoin'd,)": "19.215",
    "And now the delegates Ulysses sent,": "19.238",
    "The speedy council at his word adjourn": "19.276",
    "He spoke, and from the warriors turn'd his face": "19.309",
    "He spoke, and sudden at the word of Jove": "19.349",
    "And now he shakes his great paternal spear": "19.387",


        "THUS round Pelides breathing war and blood,": "20.1",

    "He said, and fir'd their heavenly breasts with rage:": "20.30",

    "But when the powers descending swell'd the fight,": "20.54",

    "Then thus the hero of Anchises' strain:": "20.86",

    "This said, and spirit breath'd into his breast,": "20.110",

    "Thus having said, the tyrant of the sea,": "20.144",

    "Ere yet the stern encounter join'd, begun": "20.176",

    "To this Anchises' son: ‘Such words employ": "20.199",

    "‘Such is our race: 'tis fortune gives us birth,": "20.242",

    "Then, rising ere he threw,": "20.273",

    "The great earth-shaker thus: to whom replies": "20.309",

    "With that, he left him wondering as he lay,": "20.340",

    "Thus (breathing rage through all) the hero said;": "20.373",

    "When Hector view'd, all ghastly in his gore,": "20.419",

    "With that he gluts his rage on numbers slain:": "20.455",

    "As when a flame the winding valley fills,": "20.490",


    "AND now to Xanthus' gliding stream they drove,": "21.1",
    "Now, tir'd with slaughter, from the Trojan band": "21.34",
    "Thus while he spake, the Trojan, pale with fears": "21.64",
    "These words, attended with a shower of tears": "21.97",
    "These boastful words provoke the raging god": "21.136",
    "Threatening he said: the hostile chiefs advance": "21.161",
    "He said: then from the bank his javelin tore": "21.200",
    "He said: and drove with fury on the foe": "21.233",
    "Forth bursts the hero with an angry groan:": "21.272",
    "Thus spake the gods:</l>": "21.298",
    "He said; and on the chief descends amain": "21.324",
    "He ceas'd; while, conflagration blazing round": "21.361",
    "He spoke, and smote the loud-resounding shield": "21.400",
    "Thus she, and Juno with a smile approv": "21.434",
    "Then turns his face, far beaming heavenly fires": "21.468",
    "He spoke, and pass'd: Latona, stooping low": "21.502",
    "Thus charged the reverend monarch: wide were flung": "21.537",
    "He said, and stood, collected in his might": "21.571",
        "THUS to their bulwarks, smit with panic fear,": "22.1",

    "'Ah stay not, stay not! guardless and alone;": "22.38",

    "He said, and acting what no words could say,": "22.77",

    "'And yet suppose these measures I forego,": "22.111",

    "Thus pondering, like a god the Greek drew nigh:": "22.131",

    "Then Pallas thus: 'Shall he whose vengeance forms": "22.177",

    "Her voice divine the chief with joyful mind": "22.224",

    "'Talk not of oaths,’ (the dreadful chief replies,": "22.260",

    "He spoke, and launch'd his javelin at the foe;": "22.289",

    "Prone on the field the bleeding warrior lies,": "22.337",

    "Then, forcing backward from the gaping wound": "22.367",

    "The mother first beheld with sad survey:": "22.405",

    "But not as yet the fatal news had spread": "22.437",

    "Around, a train of weeping sisters stands,": "22.473",


    "THUS humbled in the dust, the pensive train": "23.1",
    "And now a band of Argive monarchs brings": "23.35",
    "He spoke: they hear him, and the word obey;": "23.54",
    "‘And is it thou?’ (he answers;) ‘to my sight": "23.93",
    "There on the spot which great Achilles shew'd,": "23.138",
    "He said: the people to their ships return:": "23.161",
    "Nor yet the pile, where dead Patroclus lies,": "23.192",
    "’Twas when, emerging through the shades of night,": "23.226",
    "First stood the prizes to reward the force": "23.262",
    "Fir'd at his word, the rival racers rise;": "23.287",
    "‘In vain, unskilful, to the goal they strive,": "23.319",
    "Next bold Meriones was seen to rise,": "23.351",
    "The fraud celestial Pallas sees with pain,": "23.388",
    "Thus he. The coursers at their master's threat": "23.429",
    "‘Old man!’ (Oïleus rashly thus replies,)": "23.473",
    "Young Nestor follows, (who by art, not force,": "23.514",
    "Achilles smil'd: ‘The gift propos'd,’ (he cried,)": "23.555",
    "The prudent chief with calm attention heard;": "23.586",
    "He said, and plac'd the goblet at his side:": "23.624",
    "The dreadful combat great Epëus chose:": "23.664",
    "The third bold game Achilles next demands,": "23.700",
    "And now succeed the gifts ordain'd to grace": "23.740",
    "Thus sourly wail'd he, sputtering dirt and gore;": "23.784",
    "Then hurl'd the hero, thundering on the ground,": "23.826",
    "He said: experienc'd Merion took the word;": "23.859",


    "NOW from the finish'd games the Grecian band": "24.1",
    "All heaven was mov'd, and Hermes will'd to go": "24.22",
    "Then thus the Thunderer checks the imperial dame:": "24.64",
    "She spake, and veil'd her head in sable shade,": "24.93",
    "His word the silver-footed queen attends,": "24.120",
    "Then down her bow the winged Iris drives,": "24.159",
    "The hoary monarch thus: her piercing cries": "24.200",
    "Forth from his open'd stores, this said, he drew": "24.228",
    "The sons their father's wretched age revere,": "24.265",
    "‘'Tis just’ (said Priam) ‘to the Sire above": "24.299",
    "The god obeys, his golden pinions binds,": "24.339",
    "‘Thy words, that speak benevolence of mind,": "24.372",
    "‘If then thou art of stern Pelides' train,’": "24.405",
    "He said, then took the chariot at a bound,": "24.440",
    "Thus having said, he vanish'd from his eyes,": "24.468",
    "These words soft pity in the chief inspire,": "24.507",
    "To whom the king: ‘O favour'd of the skies!": "24.552",
    "He said, and, entering, took his seat of state,": "24.596",
    "With that, Achilles bade prepare the bed,": "24.643",
    "Now gods and men the gifts of sleep partake;": "24.677",
    "In thronging crowds they issue to the plains,": "24.707",
    "The mournful mother next sustains her part:": "24.746",
    "But Priam check'd the torrent as it rose:": "24.776"
}

# %%
import re
print(len(card_alignment))

basecards = {}
basecardlist = []
curchap = ''
curcard = ''
curbook = ''
curcit = ''
f = open('/Users/gcrane/github/canonical-greekLit/data/tlg0012/tlg001/tlg0012.tlg001.perseus-grc2.xml')
for l in f:

    #m = re.search('n="([^"]+)" type="textpart" subtype="book"',l)
    m = re.search('type="textpart" subtype="Book" n="([^"]+)"',l)
    if(m):
        curbook = m[1] + '.'
       # print('curbook',curbook)
    m = re.search('<milestone[^>]+n="([^"]+)[^>]+unit="card"',l)
    if(m):
        curcit = curbook + m[1]
        basecards[curcit] = 1
        basecardlist.append(curcit)

    m = re.search('type="chapter"[^>]+n="([^"]+)',l)
    if(m):
        curchap = m[1] + '.'
    m = re.search('type="subchapter"[^>]+n="([^"]+)',l)
    if(m):
        curcard = curbook + curchap +  m[1]
        basecards[curcard] = 1

newcards = {}

def additem(curdict,curitem):
    if(curitem in curdict):
        curdict[curitem] = curdict[curitem] + 1
    else:
        curdict[curitem] = 1
        

for foo in card_alignment:
    additem(newcards,str(card_alignment[foo]))

for foo in newcards:
    if(newcards[foo] > 1):
        print('extra1',foo,newcards[foo])
   # if(not str(foo) in basecards):
   #     print('extra2',foo)

i = 0
for foo in basecards:
    continue
    if(not foo in newcards):
        print('missing',foo)
    else:
        i = i + 1
        #print(i,'confirmed',foo)
# Out:
# 457

# %%
import re


f = open("/Users/gcrane/github/english_trans-dev/volumes/homer_1909/homer.iliad.pope_watson_eng2.xml")



workbuf = f.read()
workbuf = re.sub('\n([a-zA-Z\[>])',' \g<1>',workbuf)
workfbuf = re.sub('<ref target="note-([0-9]+)-','<ref n="\g<1>."',workbuf)

# workbuf = re.sub('<milestone unit="card"[^>]+>',' ',workbuf)
missed = 0
i = 0
for foo in card_alignment:
    
    if(not str(card_alignment[foo]) in basecards):
       # print('skipping',card_alignment[foo],foo)
        continue
    curkey = re.sub('\s+\/ .+','',foo)
    curkey = re.sub('\s*\\n.+','',curkey)
    curkey2 = ''
    n = workbuf.count(curkey)
    #print('test',n,foo,card_alignment[foo])
    if(not n == 1):
        curkey = foo[0:20]
        print(n,card_alignment[foo],foo,'shorthit20',curkey)

    
        n = workbuf.count(curkey)
    if(not n == 1):
        curkey = foo[0:10]
        #print('shorthit',curkey)
        n = workbuf.count(curkey)
    if(not n == 1):
        
        print(missed,n,'>'+foo+'<',card_alignment[foo],'[['+curkey+']]')
        missed = missed + 1
        continue
    i = i + 1
    #print(i,'adding',card_alignment[foo],foo)
    curmile = '<milestone unit="card" n="'+str(card_alignment[foo])+'"/>'
    workbuf = re.sub('(<milestone unit="card"[^>]+>)\s*(\[[0-9]+\])','\g<2>\g<1>',workbuf)
    workbuf = workbuf.replace(curkey,curmile+curkey)
workbuf = re.sub('(<l n=")[0-9]+\.','\g<1>',workbuf)
workbuf = re.sub('(<note[^>]+n="[0-9\.]+">)[0-9]+\s+','\g<1>',workbuf)

f.close()

workbuf =re.sub("(<l [^>]+>[']*)(<milestone unit=\"card\"[^>]+>)",'\g<2>\n\g<1>',workbuf)
#workbuf = re.sub('(<milestone unit="card" n=")[0-9]+\.','\g<1>',workbuf)

outfname = '../staging/tlg0012.tlg001.popewatson1857-eng2.xml'
outf = open(outfname,'w')
outf.write(workbuf)
outf.close()

n = workbuf.count('"card"')
print('cards',n,'should be',len(basecards))
# Out:
# cards 425 should be 425

# %%
savebuf = workbuf

f = open(outfname)
workbuf = f.read()

f.close()

addedcards = []
while( re.search('<milestone unit="card" n="([^"]+)',workbuf)):
    m = re.search('<milestone unit="card" n="([^"]+)',workbuf)
    addedcards.append(m[1])
    workbuf = re.sub('<milestone unit="card" n="([^"]+)','',workbuf,1)

for foo in basecardlist:
    if(not foo in addedcards):
        print('missing',foo)

for foo in addedcards:
    if(not foo in basecardlist):
        print('extra',foo)

for i in range(0,len(addedcards)):
    if(not addedcards[i] == basecardlist[i]):
        print('mism',i,addedcards[i], basecardlist[i])
print('checked out')
# Out:
# checked out

# %%
f = open(outfname)
inbook = ''
lastl = ''
lastrefn = 0
reflist = []
notelist = []
for l in f:
    if(re.search('</div>',l)):
        inbook = ''
    m = re.search('subtype="book" n="([0-9]+)"',l)
    if(m):
        inbook = m[1] + '.'
        curnoten = 0
        lastrefn = 0

    l = re.sub('(<ref n="[^"]+")>[0-9]+[a-z]*</ref>','\g<1>/>',l)
    l = re.sub('(<ref n=")[0-9]+\.','\g<1>'+inbook,l)
    l = re.sub('(<ref n=")([0-9]+)"','\g<1>'+inbook+'\g<2>"',l)

    m = re.search('<ref n="([0-9]+)\.([0-9]+)',l)
    if(m):
        currefn = int(m[2])
        if(not currefn == lastrefn + 1):
            print(lastrefn,currefn,l)

        lastrefn = currefn
        reflist.append(m[1] + '.' + m[2])

    m = re.search('(<note type="footnote"|<note) n="[0-9]+\.([0-9]+)"',l)
    if(m):
        curnote = inbook + m[2]
        notelist.append(curnote)
        if(not curnoten  + 1 == int(m[2])):
            print(curnoten,curnote,l,lastl)
        curnoten = int(m[2])
        lastl = l
    if(re.search('<note ',l) and not m):
        print(l)
f.close()


for foo in notelist:
    if(not foo in reflist):
        print('missref',foo)

for foo in reflist:
    if(not foo in notelist):
        print('notelist',foo)

print(len(notelist),len(reflist))
# Out:
# <p>It was in the tenth year of the siege that discord arose between Agamemnon and Achilles, from the following cause. A pestilence spread through the Grecian army, and Calchas, the chief augur of the Greeks, being consulted respecting the origin of it, declared that it proceeded from Apollo, whose priest Chryses, having come to the camp to offer ransom for his daughter, (who had been taken prisoner by Achilles at the capture of the neighbouring city of Lyrnessus, and had been assigned, in the distribution of the spoil, to Agamemnon,) had been dismissed with a contumelious refusal by Agamemnon, and had in consequence called down the anger of Apollo on the Grecian army. Calchas foretold that the pestilence would not cease till Apollo should be appeased by the surrender of the captive to her father; and Aga<note type="footnote"> 1 B. i. c. 11</note>
#
# ...

# %%
workbuf1 = re.sub('(\[[0-9]+|<div)','<ZZ>\g<1>', savebuf)



n = workbuf1.count('unit="card"')
print('cards',n,'should be',len(basecards))
i = 0
curbook = "1"
curline = "1"
cardbook = "1"
for foo in workbuf1.split('<ZZ>'):
    i = i + 1
    m = re.search('"book" n="([0-9]+)"',foo)
    if(m):
        curbook = m[1]
        cardbook = curbook
        curcard = curbook + '.1'
        curline = '1'

    m = re.search('^\[([0-9]+)',foo)
    if(m):
        curline = m[1]
    m = re.search('unit="card" n="([^"]+)"',foo)
    if(m):
        curcard = m[1]
    if(re.search('(unit="card"|"book")',foo) and curcard):
        #print('card',curcard,foo)
        cardbook,cardline = curcard.split('.')
        if(not cardbook == curbook):
            print('\nbookfail',curbook,cardbook,curline,curcard,foo)
        cardlnum = int(cardline)
        curlnum = int(curline)
        if(cardlnum < curlnum):
            print('\ntooearly',curline,curcard,foo)
        if(cardlnum > curlnum + 5):
            print('\ntoolate',curline,curcard,foo)
# Out:
# cards 425 should be 425

# %%
basecards
# Out:
# {'1.1': 1,
#  '1.33': 1,
#  '1.68': 1,
#  '1.92': 1,
#  '1.130': 1,
#  '1.172': 1,
#  '1.206': 1,
#  '1.245': 1,
#  '1.285': 1,
#  '1.312': 1,
#  '1.345': 1,
#  '1.386': 1,
#  '1.428': 1,
#  '1.458': 1,
#  '1.493': 1,
#  '1.531': 1,
#  '1.568': 1,
#  '2.1': 1,
#  '2.35': 1,
#  '2.76': 1,
#  '2.109': 1,
#  '2.155': 1,
#  '2.188': 1,
#  '2.224': 1,
#  '2.265': 1,
#  '2.301': 1,
#  '2.336': 1,
#  '2.369': 1,
#  '2.419': 1,
#  '2.459': 1,
#  '2.511': 1,
#  '2.546': 1,
#  '2.581': 1,
#  '2.615': 1,
#  '2.653': 1,
#  '2.695': 1,
#  '2.734': 1,
#  '2.780': 1,
#  '2.819': 1,
#  '2.858': 1,
#  '3.1': 1,
#  '3.38': 1,
#  '3.76': 1,
#  '3.111': 1,
#  '3.146': 1,
#  '3.191': 1,
#  '3.225': 1,
#  '3.264': 1,
#  '3.302': 1,
#  '3.340': 1,
#  '3.383': 1,
#  '3.421': 1,
#  '4.1': 1,
#  '4.50': 1,
#  '4.85': 1,
#  '4.127': 1,
#  '4.183': 1,
#  '4.223': 1,
#  '4.265': 1,
#  '4.310': 1,
#  '4.350': 1,
#  '4.401': 1,
#  '4.446': 1,
#  '4.488': 1,
#  '4.517': 1,
#  '5.1': 1,
#  '5.43': 1,
#  '5.84': 1,
# ...
