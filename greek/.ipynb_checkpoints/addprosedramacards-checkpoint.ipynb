# %%
card_alignment = {
    "O treu verbundnes Schwesterhaupt, Ismene, sprich,": "1",
    "Was mag ich, o Unsel'ge, wenn dies also liegt,": "39",
    "Nicht mehr verlang' ich's, noch wenn jetzo du sogar": "69",
    "Strahl der Sonne, das schönste Licht,": "100",
    "ihn, welchen ins Land zur Befehdung rief": "110",
    "Jener, über den Häusern, um-": "117",
    "Denn Zeus hafst schwer grofssprechender Zung'": "127",
    "Und zu der dröhnenden Erde geschmettert fiel er,": "134",
    "Denn Sieben um sieben der Thore gestellt,": "141",
    "Aber es kam die gepriesene Siegesgöttin,": "148",
    "Doch Kreon kommt des Menökeus Sohn,": "155",
    "Ihr Männer, unsers Landes Glück hob Götterhuld": "162",
    "Daſs Hüter nun ihr dessen seid, was ich gesagt!": "211",
    "Was ist es, daſs dich also fafst Muthlosigkeit?": "237",
    "Herr, ob wol dies Eräugniſs gar ein Götterwerk,": "278",
    "Gönnst du zu reden, oder soll ich so von hier?": "315",
    #"Vieles Gewalt'ge lebt, und nichts": "332",
    "Flüchtig gesinnter Vögel Schwarm": "343",
    "Die Rede, den luftigen Flug des Denkens ersann er, erfand": "354",
    "Mit listiger Künste Geschick wohl über Verhoffen begabt": "365",
    "O Wunder, dem Blick kaum trau' ich, und doch": "376",
    "Was ist es? wozu kam gerade recht ich her?": "384",
    "So war der Hergang. Als wir eben hingeeilt,": "407",
    "Dich, die zum Boden senkt das Haupt, dich fragen wir:": "441",
    "Doch wisse nur, die allzustarre Sinnesart,": "471",
    "Was also säumst du? Mir ist deiner Worte keins": "499",
    "Sieh dort vor dem Thor Ismene'n sich nahn,": "526",
    "Du die zu Haus, anschleichend mir, der Natter gleich,": "531",
    "Doch nicht mit meines Herzens ungesprochnem Wort!": "556",
    "Glückselige, deren Geschick nie Weh gekostet!": "583",
    "Im Hause des Labdakos seh' uraltes Leid ich": "593",
    "Wer mag deine Gewalt, o Zeus, kühn aufhalten in frevlem Hochmuth,": "605",
    "Denn die schweifende Hoffnung beut oft wohl vielen der Männer Segen,": "615",
    "Sieh, Hämon erscheint, dein jüngester Sprofs.": "626",
    "Bald wissen wir es besser als der Seher weifs.": "631",
    "Wofern uns Alter nicht den Sinn befangen hält,": "681",
    "In solchem Alter sollen also wir von dem": "724",
    "Wahrhaftig? Nimmer, beim Olympos, wisse dies,": "758",
    "Auch edlen Geist reiſsest du hin": "781",
    "O Eros, Allsieger im Kampf,": "791",
    "Schon werd' auch ich weit über das Recht": "801",
    "O seht mich, o Bürger des Vaterlandes,": "806",
    "Ruhmvoll denn gehst und mit Lobe geschmückt": "817",
    "Wohl hört' ich, ging Tantalos' Tochter, sie die": "823",
    "Doch Göttin ist sie, von der Götter Geschlecht,": "834",
    "Weh mir! Verlagt werd' ich! Warum, o Vatergötter,": "839",
    "Vorschreitend bis zum Äufsersten": "853",
    "Du regtest schmerzvollesten Gram mir auf im Busen,": "858",
    "Wohl heilig Todter Heiligung!": "872",
    "Ohn' Hymens Lied, verlassen, klaglos,": "876",
    "Wifst ihr, dafs keiner vor dem Tod mit Klaggesang": "883",
    #"O Grab, o Hochzeitkammer, unterirdische": "891",
    "Noch derselbige Sturm tobt rastlos fort": "929",
    "Auch der Danaë Leib mufste des Himmels": "944",
    "Fest ward Dryas' im Zorn heftig entbrannter": "955",
    "An den Kyanischen Wassern des flutenden Doppelmeers,": "966",
    "Und es vergingen die Armen bejammernd das Jammerleid,": "977",
    "Ihr Thebens Edle, gleichen Weg her kommen wir,": "988",
    "O Greis, ihr schieſset wie die Schützen nach dem Ziel": "1033",
    "So wisse wohl auch, daſs der raschen Kreise du": "1064",
    "Der Mann, o Herr, ging grauenvoll weissagend fort.": "1091",
    "Vielnam'ger, der Kadmischen Jungfrau wonnig Kleinod!": "1115",
    "Dich schauet vom Doppelgeklipp' auflodernd helle": "1126",
    "die weit du, weit vorziehst an Ehren jeglicher Stadt,": "1137",
    "Io du, glutaussprühn'der Sterne führend den Chor,": "1146",
    "Die ihr des Kadmos und Amphions Haus umwohnt,": "1155",
    "O Bürger alle, welches Wort vernahm ich hier,": "1183",
    "Des bangen Herrn Geboten folgend sahen wir": "1219",
    "Wie magst du das wol deuten? Fort schon ist die Frau,": "1244",
    "Hier nahet er selbst, der Gebieter, heran;": "1257",
    "O sinnloser Sinne todschwangere": "1261",
    "Ach daſs zu spät doch, seh' ich, du das Recht erkennst!": "1270",
    "O Herr, wie einer, der so recht im Erbbesitz": "1278",
    "Was giebt es wieder Schlimmes? was ist noch mir schlimm?": "1281",
    "O weh! nie versöhnlich Reich, Hades' Schlund,": "1284",
    "Du kannst es sehen; nicht im Innern ist sie mehr.": "1293",
    "Dies andre zweite Leiden schau' Elender ich!": "1294",
    #"Als scharfgetroffen um den Altar hin sie lag,": "1301",
    "Vor Angst schaudr' ich auf! Warum stöfst nicht wer": "1306",
    "O weh, weh! der Menschen kein andrer nimmt": "1317",
    "O komm, o komm, erschein', unsrer Todesloos' herrlichstes,": "1328",
    "Dies birgt die Zukunft; Sorg' erheischt die Gegenwart:": "1334",
    "Hinweg führet denn mich den Vernichteten,": "1339",
    "Glückselig zu seyn, thut Weisheit noth": "1347"
}

# %%
import re
print(len(card_alignment))

basecards = {}
f = open('/Users/gcrane/github/canonical-greekLit/data/tlg0011/tlg002/tlg0011.tlg002.perseus-grc2.xml')
for l in f:
    m = re.search('<milestone unit="card" n="([^"]+)',l)
    if(m):
        basecards[m[1]] = 1

newcards = {}

def additem(curdict,curitem):
    if(curitem in curdict):
        curdict[curitem] = curdict[curitem] + 1
    else:
        curdict[curitem] = 1
        

for foo in card_alignment:
    additem(newcards,str(card_alignment[foo]))

for foo in newcards:
    if(newcards[foo] > 1):
        print('extra1',foo,newcards[foo])
    if(not str(foo) in basecards):
        print('extra2',foo)

i = 0
for foo in basecards:
    if(not foo in newcards):
        print('missing',foo)
    else:
        i = i + 1
        #print(i,'confirmed',foo)
# Out:
# 81

# %%
import re


f = open("../translations/goodlines.tlg0011.tlg002.boeckh1884-deu1.xml")

workbuf = f.read()
missed = 0
i = 0
for foo in card_alignment:
    if(not str(card_alignment[foo]) in basecards):
        #print('skipping',foo)
        continue
    curkey = foo
    n = workbuf.count(curkey)
    if(not n == 1):
        curkey = foo[0:10]
    n = workbuf.count(curkey)
    if(not n == 1):
        
        print(missed,n,foo,card_alignment[foo])
        missed = missed + 1
        continue
    i = i + 1
    print(i,'adding',card_alignment[foo],foo)
    curmile = '<milestone unit="card" n="'+str(card_alignment[foo])+'" edRef="Storr"/>'
    workbuf = workbuf.replace(curkey,curmile+curkey)

f.close()
outfname = '../staging/tlg0011.tlg002.boeckh1884-deu2.xml'
outf = open(outfname,'w')
outf.write(workbuf)
outf.close()
# Out:
# 1 adding 1 O treu verbundnes Schwesterhaupt, Ismene, sprich,
# 2 adding 39 Was mag ich, o Unsel'ge, wenn dies also liegt,
# 3 adding 69 Nicht mehr verlang' ich's, noch,
# 4 adding 100 Strahl der Sonne, das schönste Licht,
# 5 adding 110 ihn, welchen ins Land zur Befehdung rief
# 6 adding 117 Jener, über den Häusern, um-
# 7 adding 127 Denn Zeus hafst schwer grofssprechender Zung'
# 8 adding 134 Und zu der dröhnenden Erde geschmettert fiel er,
# 9 adding 141 Denn Sieben um sieben der Thore gestellt,
# 10 adding 148 Aber es kam die gepriesene Siegesgöttin,
# 11 adding 155 Doch Kreon kommt des Menökeus Sohn,
# 12 adding 162 Ihr Männer, unsers Landes Glück hob Götterhuld
# 13 adding 211 Daſs Hüter nun ihr dessen seid, was ich gesagt!
# 14 adding 237 Was ist es, daſs dich also fafst Muthlosigkeit?
# 15 adding 278 Herr, ob wol dies Eräugniſs gar ein Götterwerk,
# 16 adding 315 Gönnst du zu reden, oder soll ich so von hier?
# 17 adding 343 Flüchtig gesinnter Vögel Schwarm
# 18 adding 354 Die Rede, den luftigen Flug des Denkens ersann er, erfand
# 19 adding 365 Mit listiger Künste Geschick wohl über Verhoffen begabt
# 20 adding 376 O Wunder, dem Blick kaum trau' ich, und doch
# 21 adding 384 Was ist es? wozu kam gerade recht ich her?
# 22 adding 407 So war der Hergang. Als wir eben hingeeilt,
# 23 adding 441 Dich, die zum Boden senkt das Haupt, dich fragen wir:
# 24 adding 471 Doch wisse nur, die allzustarre Sinnesart,
# 25 adding 499 Was also säumst du? Mir ist deiner Worte keins
# 26 adding 526 Sieh dort vor dem Thor Ismene'n sich nahn,
# 27 adding 531 Du die zu Haus, anschleichend mir, der Natter gleich,
# 28 adding 556 Doch nicht mit meines Herzens ungesprochnem Wort!
# 29 adding 583 Glückselige, deren Geschick nie Weh gekostet!
# 30 adding 593 Im Hause des Labdakos seh' uraltes Leid ich
# 31 adding 605 Wer mag deine Gewalt, o Zeus, kühn aufhalten in frevlem Hochmuth,
# 32 adding 615 Denn die schweifende Hoffnung beut oft wohl vielen der Männer Segen,
# 33 adding 626 Sieh, Hämon erscheint, dein jüngester Sprofs.
# 34 adding 631 Bald wissen wir es besser als der Seher weifs.
# 35 adding 681 Wofern uns Alter nicht den Sinn befangen hält,
# 36 adding 724 In solchem Alter sollen also wir von dem
# 37 adding 758 Wahrhaftig? Nimmer, beim Olympos, wisse dies,
# 38 adding 781 Auch edlen Geist reiſsest du hin
# 39 adding 791 O Eros, Allsieger im Kampf,
# 40 adding 801 Schon werd' auch ich weit über das Recht
# 41 adding 806 O seht mich, o Bürger des Vaterlandes,
# 42 adding 817 Ruhmvoll denn gehst und mit Lobe geschmückt
# 43 adding 823 Wohl hört' ich, ging Tantalos' Tochter, sie die
# 44 adding 834 Doch Göttin ist sie, von der Götter Geschlecht,
# 45 adding 839 Weh mir! Verlagt werd' ich! Warum, o Vatergötter,
# 46 adding 853 Vorschreitend bis zum Äufsersten
# 47 adding 858 Du regtest schmerzvollesten Gram mir auf im Busen,
# 48 adding 872 Wohl heilig Todter Heiligung!
# 49 adding 876 Ohn' Hymens Lied, verlassen, klaglos,
# 50 adding 883 Wifst ihr, dafs keiner vor dem Tod mit Klaggesang
# 51 adding 929 Noch derselbige Sturm tobt rastlos fort
# 52 adding 944 Auch der Danaë Leib mufste des Himmels
# 53 adding 955 Fest ward Dryas' im Zorn heftig entbrannter
# 54 adding 966 An den Kyanischen Wassern des flutenden Doppelmeers,
# 55 adding 977 Und es vergingen die Armen bejammernd das Jammerleid,
# 56 adding 988 Ihr Thebens Edle, gleichen Weg her kommen wir,
# 57 adding 1033 O Greis, ihr schieſset wie die Schützen nach dem Ziel
# 58 adding 1064 So wisse wohl auch, daſs der raschen Kreise du
# 59 adding 1091 Der Mann, o Herr, ging grauenvoll weissagend fort.
# 60 adding 1115 Vielnam'ger, der Kadmischen Jungfrau wonnig Kleinod!
# 61 adding 1126 Dich schauet vom Doppelgeklipp' auflodernd helle
# 62 adding 1137 die weit du, weit vorziehst an Ehren jeglicher Stadt,
# 63 adding 1146 Io du, glutaussprühn'der Sterne führend den Chor,
# 64 adding 1155 Die ihr des Kadmos und Amphions Haus umwohnt,
# 65 adding 1183 O Bürger alle, welches Wort vernahm ich hier,
# 66 adding 1219 Des bangen Herrn Geboten folgend sahen wir
# 67 adding 1244 Wie magst du das wol deuten? Fort schon ist die Frau,
# 68 adding 1257 Hier nahet er selbst, der Gebieter, heran;
# 69 adding 1261 O sinnloser Sinne todschwangere
# 70 adding 1270 Ach daſs zu spät doch, seh' ich, du das Recht erkennst!
# 71 adding 1278 O Herr, wie einer, der so recht im Erbbesitz
# 72 adding 1281 Was giebt es wieder Schlimmes? was ist noch mir schlimm?
# 73 adding 1284 O weh! nie versöhnlich Reich, Hades' Schlund,
# 74 adding 1293 Du kannst es sehen; nicht im Innern ist sie mehr.
# 75 adding 1294 Dies andre zweite Leiden schau' Elender ich!
# 76 adding 1306 Vor Angst schaudr' ich auf! Warum stöfst nicht wer
# 77 adding 1317 O weh, weh! der Menschen kein andrer nimmt
# 78 adding 1328 O komm, o komm, erschein', unsrer Todesloos' herrlichstes,
# 79 adding 1334 Dies birgt die Zukunft; Sorg' erheischt die Gegenwart:
# 80 adding 1339 Hinweg führet denn mich den Vernichteten,
# 81 adding 1347 Glückselig zu seyn, thut Weisheit noth
