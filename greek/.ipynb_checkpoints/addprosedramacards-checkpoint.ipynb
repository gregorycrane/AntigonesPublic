# %%
card_alignment = {
    "¡Oh compañera cabecita de mi propia hermana Ismena!": "1",
    "¿Y qué, ¡oh desdichada!, si las cosas están así, podré remediar yo": "39",
    "Ni te lo mandaré, ni aunque luego lo quieras hacer, tendré gusto en que me ayudes.": "69",
    "¡Rayo del Sol, la más hermosa luz de las que antes brillaban en Tebas": "100",
    "Ejército que en contra nuestra había levantado Polinices": "110",
    "y después de asediar": "117",
    "Júpiter, pues, odia las bravatas de orgullosa lengua": "127",
    "Y sobre el suelo que retumbó al chocar con él, cayó herido del rayo": "134",
    "Pues los siete jefes que en las siete puertas se habían colocado": "141",
    "Pero, puesto que la gloriosa victoria llegó felicitando a Tebas": "148",
    "Pero he ahí al rey de esta tierra, a Creonte, el hijo de Meneceo": "155",
    "¡Ciudadanos! Los dioses al fin han enderezado los asuntos de la ciudad": "162",
    "Sea como te place, Creonte, hijo de Meneceo, respecto de los amigos": "211",
    "¿Qué es lo que te causa ese desaliento?": "237",
    "¡Rey!, a mí, en verdad, me brujulea el corazón hace ya rato": "278",
    "¿Me permites hablar, o doy la vuelta y me voy?": "315",
    "Y de la raza ligera de las aves, tendiendo redes, se apodera": "343",
    "Y en el arte de la palabra, y en el pensamiento sutil como el viento": "354",
    "Y poseyendo la industriosa habilidad del arte más de lo que podía esperarse": "365",
    "Ante el admirable prodigio que se me presenta a la vista, estoy dudando.": "376",
    "Señor, para los hombres nada hay irrevocable, porque la reflexión modifica": "384",
    "La cosa ocurrió de esta manera: cuando yo llegué asustado por las terribles": "407",
    "Tú, tú que inclinas la cara hacia el suelo, ¿afirmas o niegas haber hecho eso?": "441",
    "Demuestra esa índole tenaz que es hija de padre tenaz; no sabe rendirse": "471",
    "¿Pues qué esperas ya? A mi, tus razonamientos": "499",
    "Ya en la puerta tienes a Ismena derramando lágrimas de amor por su hermana": "526",
    "¡Tú, la que deslizándote por palacio como una víbora, sin advertirlo yo": "531",
    "Pero mis razones no quedaron sin decir.": "556",
    "¡Dichosos todos los que pasan la vida sin probar un infortunio!": "583",
    "Sobre las antiguas calamidades de la familia de los Labdácidas veo": "593",
    "Tu poder, ¡oh Júpiter!, ¿qué hombre en su arrogancia lo podrá resistir": "605",
    "Pues, en verdad, la vagarosa esperanza": "615",
    "Pero he ahí a Hemón, el más joven pimpollo de tus hijos.": "626",
    "Pronto lo sabremos de él, mejor que de cualquier adivino. ¡Hijo!": "631",
    "A mi, si no es que por la edad chocheo, me parece razonable lo que has dicho.": "681",
    "Rey, conviene que si algo oportuno dice éste, lo atiendas": "724",
    "¿Si? Pues, por el Olimpo, sabe que no te alegrarás de haberme injuriado": "758",
    "¡Amor invencible en la pelea! ¡Amor que en el corazón te infundes": "781",
    "Tú de los hombres justos arrancas injustas determinaciones, para arruinarlos": "791",
    "Ahora, en verdad, yo mismo me dejo llevar fuera de lo debido": "801",
    "Miradme, ¡oh ciudadanos de mi patria!, comenzando mi último viaje": "806",
    "Pues ilustre y llena de gloria te vas a ese abismo de la muerte": "817",
    "Ya <choice><sic>oi</sic><corr>oí</corr></choice> contar": "823",
    "Pero ella, en verdad, es diosa, y de un dios había nacido": "834",
    "¡Ay, cómo se mofan de mi! ¿Por qué, por los dioses patrios, no aguardáis": "839",
    "Por haber querido traspasar los límites del atrevimiento, chocaste": "853",
    "Llegaste a poner tu lengua en mis más dolorosos remordimientos: el infortunio": "858",
    "Respetar a los muertos, es piedad; y el imperio, sea cualquiera en quien resida": "872",
    "Sin consuelos, sin amigos, sin himeneo, emprendo mi último viaje.": "876",
    "¿Acaso no sabéis que de cantos y lloros antes de morir no hay ninguno": "883",
    "Aún la están dominando los ímpetus de las mismas pasiones.": "929",
    "También sufrió Dánae cambiar la celestial luz por las tinieblas": "944",
    "<choice><sic>Fué</sic><corr>Fue</corr></choice> encadenado": "955",
    "Y junto a las negras rocas de los dos mares están las orillas del Bósforo": "966",
    "y deshaciéndose en lágrimas los desdichados, lloraban la desdichada suerte": "977",
    "Señores de Tebas: venimos dos en compañía con los ojos de uno solo": "988",
    "¡Oh anciano! Todos, como arqueros al blanco, disparáis contra mí": "1033",
    "Pero tú también has de saber que ya no verificará el Sol muchas revoluciones": "1064",
    "Ese hombre, ¡oh rey!, se va después de anunciar terribles": "1091",
    "¡Oh dios de muchos nombres, que de la ninfa Cadmea eres orgullo": "1115",
    "Hacia ti se dirige la llama que brilla sobre este monte de dos cimas": "1126",
    "extraordinariamente honras sobre todas las ciudades, con tu madre": "1137",
    "¡Oh jefe del coro de los astros que respiran fuego, inspector": "1146",
    "¡Vecinos de Tebas y de la mansión de Anfión! Nunca más yo admiraré": "1155",
    "¡Oh ciudadanos todos!": "1183",
    "Y mira lo que vimos al cumplir las órdenes de nuestro abatido señor en el fondo": "1219",
    "¿Qué conjeturas ahora? Esa mujer ha desaparecido sin proferir buena": "1244",
    "Pues he <choice><sic>ahi</sic><corr>ahí</corr></choice> al mismo": "1257",
    "¡Oh crueles y mortales pecados de mis desatentados consejos!": "1261",
    "¡Ay!, que tarde parece que reconoces la justicia.": "1270",
    "¡Ah, señor! ¡Cómo teniendo y sintiendo la desgracia que llevas": "1278",
    "¿Qué hay, pues, peor que el mismo mal?": "1281",
    "¡Ay, ay, implacable puerto del infierno! ¿Por qué, pues, a mí": "1284",
    "Puedes verla, pues no está en el interior de palacio.": "1293",
    "¡Ay de mí! ¡Esta es otra nueva desgracia que veo! ¡Infeliz de mí!": "1294",
    "¡Ayay, ayay! Estoy pasmado de horror. ¿Por qué no me matáis con espada": "1306",
    "¡Ay de mí! No se impute nada de esto a otro hombre, porque ha sucedido": "1317",
    "¡Venga, venga! ¡Aparezca el último y más deseado de mis infortunios": "1328",
    "Esas cosas están por venir. De las presentes conviene que nos preocupemos": "1334",
    "Echad de aquí a un hombre inútil, que, ¡ay, hijo!, te maté sin querer": "1339",
    "La prudencia es la primera condición para la felicidad; y es menester": "1347",
}

# %%
import re
print(len(card_alignment))

basecards = {}
f = open('/Users/gcrane/github/canonical-greekLit/data/tlg0011/tlg002/tlg0011.tlg002.perseus-grc2.xml')
for l in f:
    m = re.search('<milestone unit="card" n="([^"]+)',l)
    if(m):
        basecards[m[1]] = 1

newcards = {}

def additem(curdict,curitem):
    if(curitem in curdict):
        curdict[curitem] = curdict[curitem] + 1
    else:
        curdict[curitem] = 1
        

for foo in card_alignment:
    additem(newcards,str(card_alignment[foo]))

for foo in newcards:
    if(newcards[foo] > 1):
        print('extra1',foo,newcards[foo])
    #if(not str(foo) in basecards):
     #   print('extra2',foo)

i = 0
for foo in basecards:
    if(not foo in newcards):
        print('missing',foo)
    else:
        i = i + 1
        #print(i,'confirmed',foo)
# Out:
# 81

# %%
import re


f = open("../translations/tlg0011.tlg002.bolufer1921-spa1.xml")

workbuf = f.read()
missed = 0

for foo in card_alignment:
    if(not str(card_alignment[foo]) in basecards):
        #print('skipping',foo)
        continue
    curkey = foo
    n = workbuf.count(curkey)
    if(not n == 1):
        curkey = foo[0:10]
    n = workbuf.count(curkey)
    if(not n == 1):
        
        print(missed,n,foo,card_alignment[foo])
        missed = missed + 1
        continue
    curmile = '<milestone unit="card" n="'+str(card_alignment[foo])+'" edRef="Storr"/>'
    workbuf = workbuf.replace(curkey,curmile+curkey)

f.close()
outfname = '../staging/tlg0011.tlg002.bolufer1921-spa2.xml'
outf = open(outfname,'w')
outf.write(workbuf)
outf.close()
