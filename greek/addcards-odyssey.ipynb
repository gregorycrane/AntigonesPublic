# %%
card_alignment =   {
"That man, tell me O Muse the song of that man": "1.1",
    "Then owl-vision Athena said, [45] “Father, son of Kronos": "1.44",
    "[80] And owl-vision Athena said, “Father, son of Kronos": "1.80",
    "He led the way as he spoke, and Athena followed": "1.125",
    "And owl-vision Athena answered, “I will tell you truly": "1.178",
    "[230] “Sir,” said the spirited Telemachus, “as": "1.230",
    "[280] to take the best ship you can get, with a": "1.280",
    "[325] The famed singer was singing for them": "1.325",
    "But the suitors were clamorous throughout the covered halls": "1.365",
    "Then, Antinoos, son of Eupeithes, said, “The gods": "1.383",
    "Then Eurymakhos, son of Polybos, answered": "1.399",
    "The suitors then returned to their singing and": "1.421",
    "Now when the child of morning, rosy-fingered Dawn, appeared, dear Telemachus rose and dressed himself.": "2.1",
    "[35] Telemachus took this speech as of good omen": "2.39",
    "Every one was very sorry for him, but they all sat still": "2.84",
    "The spirited Telemachus answered, [130] “Antinoos": "2.129",
    "Eurymakhos, son of Polybos, then said, “Go home,": "2.177",
    "With these words he sat down, [225] and Mentor": "2.224",
    "As he thus prayed, Athena came close up to him": "2.267",
    "“Antinoos,” answered the spirited Telemachus": "2.309",
    "This was how they talked. But Telemachus went down": "2.337",
    "When dear Eurykleia heard this she began to cry": "2.361",
    "When the sun had set and darkness was over all the land, she got": "2.388",
    "But as the sun was rising from the fair sea": "3.1",
    "“Some things, Telemachus,” answered owl-vision Athena": "3.25",
    "As he spoke he handed her the cup. Athena": "3.51",
    "The spirited Telemachus answered boldly": "3.79",
    "“My friend,” answered Nestor": "3.102",
    "it seemed that Menelaos was for sailing homeward" : "3.141",
    "Therefore, my dear young friend, I returned without hearing": "3.184",
    "[210] “My friend,” said Nestor, the charioteer of Gerenia": "3.210",
    "Then owl-vision goddess Athena said, [230] “Telemachus": "3.229",
    "“I will tell you truly [alēthēs],” answered Nestor": "3.254",
    "Meanwhile Menelaos and I were on our way home from Troy," : "3.276",
    "As he spoke the sun set and it came on dark": "3.329",
    "Then the owl-vision goddess Athena answered": "3.356",
    "When she had thus spoken, she flew away in the form": "3.371",
    "Now when the child of morning, rosy-fingered Dawn, appeared, [405]": "3.404",
    "When they had done praying and sprinkling the barley meal Thrasymedes": "3.447",
    "Meanwhile lovely Polykaste, [465] Nestor’s youngest daughter": "3.464",
    "Then they reached Pherai where Diokles lived": "3.487",

    # book 4
"They reached the low-lying city of Lacedaemon,": "4.1",
    "When the servants had washed them and anointed them with oil, [50]": "4.49",
    "notice the flash [steropē] of bronze [khalkos] as its light": "4.71",
    "I often grieve, as I sit here in my house": "4.100",
    "“My dear wife,” replied fair-haired Menelaos, “I see the likeness": "4.147",
    "Thus did he speak, and his words set them all to weeping. Helen": "4.183",
    "Then Zeus’ daughter Helen turned her thoughts to another matter. [220]": "4.219",
    "[265] Then fair-haired Menelaos said": "4.265",
    "“And what, Telemachus, has led you to take this": "4.315",
    "In Egypt did they hold me up, the gods did": "4.351",
    "‘Stranger,’ said she, shining among goddesses, ‘I will make": "4.398",
    "Meanwhile the goddess fetched me up four seal skins from": "4.435",
    "I was broken-hearted when I heard that I must go back all that long": "4.481",
    "But your brother [= Agamemnon] escaped from the forces": "4.512",
    "‘The third man,’ he answered, [555] ‘is Odysseus, son": "4.554",
    "“Son of Atreus,” replied the spirited Telemachus, “do not": "4.593",
    "Antinoos and Eurymakhos, who were their ringleaders and much": "4.625",
    "[675] It was not long before Penelope": "4.675",
    "[715] Then he went downstairs again, leaving Penelope in an agony of grief": "4.715",
    "With these words she made her mistress leave off crying, and dried": "4.758",
    "Then owl-vision goddess Athena turned her thoughts to another": "4.795",
    "[810] “Sister, why have you come here?" : "4.810",

    # book 5
"And now, as Dawn rose from her": "5.1",
    "[50] then he swooped down through the firmament": "5.50",
    "As she spoke she drew a table loaded with": "5.92",
    "[145] “Then send him away,” said Hermes, “and": "5.145",
    "When she had thus spoken she led the way rapidly before him, and Odysseus": "5.192",
    "When the child of morning, rosy-fingered Dawn, appeared, Odysseus put on his khiton and cloak, [230]": "5.228",
    "In four days he had completed the whole work, and on the fifth shining": "5.262",
    "As he spoke a sea broke over him with": "5.313",
    "333 He [= Odysseus] was seen by the daughter of Kadmos.": "5.339",
    "While he was thus in two minds, Poseidon,": "5.365",
    "Odysseus’ heart now began to fail him, and": "5.408",
    "Then the god stayed his stream and stilled the": "5.451",
    "So here long-suffering great Odysseus slept, overcome by": "6.1",
    "By and by morning came, throned in splendor,": "6.48",
    "When they reached the water side they went to": "6.85",
    "As he said this he crept from under his": "6.127",
    "I can only compare you to a young palm tree which": "6.162",
    "Then the maids left off running away and began": "6.211",
    "Meanwhile, Nausicaa of the white arms turned her thoughts to another": "6.251",
    "If, therefore, [290] you want my father to": "6.288",
    "Thus, then, did long-suffering great Odysseus wait and": "7.1",
    "Then she led the way, and Odysseus followed": "7.37",
    "Speaking thus, Athena [Athēnē], with the looks of": "7.77",
    "As the Phaeacians are the best sailors in the world,": "7.107",
    "Then he sat down on the hearth among the": "7.152",
    "It is possible, however, that the stranger": "7.198",
    "And resourceful Odysseus answered, “It would be a": "7.240",
    "Sick and sorry as I was I slept among": "7.287",
    "and that you may be sure of this I will": "7.317",

    # book 8
    "Now when the child of morning, rosy-fingered Dawn, appeared, Alkinoos,": "8.1",
    "The fifty-two picked [krinein] oarsmen went to the": "8.46",
    "The herald came near, bringing with him a singer": "8.62",
    "These things, then, the singer sang, whose fame goes far and": "8.83",
    "The foot races came first. The course was set": "8.121",
    "“For shame, sir,” answered resourceful Odysseus, fiercely": "8.165",
    "Much-enduring great Odysseus was glad [200] when he found": "8.199",
    "Let’s get started. I want the best of the": "8.250",
    "She was not unwilling, so they went to the": "8.295",
    "The immortal gods burst out laughing as they": "8.343",
    "The hallowed king was delighted at this, and exclaimed": "8.385",
    "Then Arete told her maids to set a large": "8.433",
    "When he had said this, he seated himself beside": "8.469",
    "So these were the things that the singer [aoidos]": "8.521",
    "Therefore, sir, do you on your part affect no": "8.550",
    "And resourceful Odysseus answered, “King Alkinoos, pre-eminent among": "9.1",
    "Meanwhile the Kikones cried out for help to other": "9.47",
    "I was driven thence by foul winds for a": "9.82",
    "Now off their harbor there lies a wooded and": "9.116",
    "thus through the livelong day to the going down": "9.161",
    "I told my men to draw the ship ashore, and stay": "9.193",
    "We lit a fire, offered some of the cheeses": "9.231",
    "He said this to draw me out, but I": "9.281",
    "In the end I thought it would be the": "9.318",
    "I then gave him some more; three times did": "9.360",
    "But Polyphemus shouted to them from inside the cave": "9.409",
    "As he spoke he drove the ram outside, but": "9.461",
    "But I would not listen to them, and shouted": "9.500",
    "Thus did he pray, and Poseidon heard his": "9.536",

    "Thence we went on to the Aeolian island where lives": "10.1",
    "Nine days and nine nights did we sail, and on": "10.28",
    "Thus they talked and evil counsels prevailed. They loosed the": "10.46",
    "Thence we sailed sadly on till the men were worn": "10.77",
    "When we reached the harbor we found it land-locked under": "10.87",
    "Thence we sailed sadly on, glad to have escaped death": "10.133",
    "‘Look here my friends,’ said I, ‘we are not": "10.174",
    "Then they uncovered their heads upon the sea shore [180]" : "10.178",
    "‘My friends, I am speaking this way because I do": "10.189",
    "So I spoke. And their heart was broken": "10.198",
    "twenty-two men, and they wept, as also did we": "10.208",
    "Then I took my sword of bronze and slung it": "10.261",
    "‘Stay where you are, then,’ answered I, ‘eating": "10.270",
    "As he spoke he pulled the herb out of the": "10.302",
    "You must be Odysseus of many turns [polutropos], about": "10.330",
    "So she swore at once as I had told her": "10.345",
    "When Circe saw me sitting there without eating, and": "10.375",
    "When I had said this she went straight through the": "10.388",
    "As soon as I got down to my ship and": "10.406",
    "Then the men would have come with me at once, but Eurylokhos": "10.428",
    "Thus did she speak and we assented. We stayed": "10.466",
    "So she swore at once as I had told her, and": "10.475",
    "And the goddess answered, ‘Resourceful Odysseus, noble son of": "10.487",
    "I was dismayed when I heard this. I sat up": "10.496",
    "‘You will want no guide,’ she answered; ‘raise your": "10.503",
    "It was day-break by the time she had done speaking": "10.541",
    "Then I went about among the men everywhere all over": "10.546",
    "When I had got the men together I said to": "10.561",
    "Then, when we had got down to the sea shore": "11.1",
    "All day long her sails were full as she held": "11.11",
    "Here Perimedes and Eurylokhos held the victims, while I": "11.23",
    'The first spirit [<foreign xml:lang="xgrc">psūkhē</foreign>] that came': "11.51",
    "Thus, then, did we sit and hold sad talk": "11.81",
    "Then came also the spirit [psūkhē] of Theban Teiresias": "11.90",
    "So he spoke, and I [= Odysseus] drew back": "11.97",
    "‘It’s your homecoming [nostos] that you seek, a homecoming": "11.100",
    "‘But you will avenge the outrages committed by those": "11.118",
    "‘This,’ I answered, ‘must be as it may please the gods, [140]": "11.138",
    "Then the spirit [psūkhē] of Teiresias went back to": "11.150",
    "‘Mother,’ said I, [165] ‘I was forced to": "11.163",
    "My mother answered, ‘Your wife still remains in your": "11.180",
    "Then I tried to find some way [205] of": "11.204",
    "‘My son,’ she answered, ‘most ill-fated of all": "11.215",
    "Thus did we converse, and then proud Persephone sent": "11.225",
    "The first I saw was gloriously descended Tyro. She": "11.235",
    "Then he dived under the sea, and she in": "11.253",
    "Next to her I saw Antiope, daughter to Asopos": "11.260",
    "Then I saw Alkmene, the wife of Amphitryon, who": "11.266",
    "I also saw fair Epikaste, mother of King Oedipus": "11.271",
    "Then I saw Khloris, surpassingly lovely, whom Neleus married": "11.281",
    "And I saw Leda the wife of Tyndareus, who": "11.298",
    "After her I saw Iphimedeia, wife of Aloeus, who": "11.305",
    "Then I saw Phaedra, and Procris, and fair": "11.321",
    "I also saw Maira and Klymene and hateful Eriphyle": "11.326",
    "Here he ended, and the guests sat all of": "11.333",
    "Then spoke the aged hero Ekheneus who was one": "11.342",
    "“The thing shall be done,” exclaimed Alkinoos, “as": "11.347",
    "And resourceful Odysseus answered, [355] “Great King Alkinoos": "11.354",
    "“Odysseus,” replied Alkinoos, “not one of us who": "11.361",
    "“Great Alkinoos, pre-eminent among all people,” answered reasourceful": "11.377",
    "When chaste Persephone had dismissed the female spirits [psūkhai]": "11.385",
    "‘Resourceful Odysseus,’ he answered, [405] ‘noble son of": "11.404",
    "‘Be sure, therefore,’ continued Agamemnon, ‘and not be": "11.440",
    "As we two sat weeping and talking thus sadly with": "11.462",
    "The psūkhē of the fleet descendant of Aiakos knew": "11.467",
    "And I said, ‘Achilles, son of Peleus, foremost": "11.477",
    "‘Say not a word,’ he answered, ‘in death’s": "11.486",
    "‘I have heard nothing,’ I answered, ‘of stately": "11.504",
    "When I had told him this, the spirit [psūkhē]": "11.538",
    "The spirits [psūkhai] of other dead men stood": "11.541",
    "There I saw Minos, radiant son of Zeus, [568]": "11.567",
    "After him I saw huge Orion in a meadow full": "11.572",
    "And I saw Tityos, glorious son of Gaia, stretched": "11.576",
    "I saw also the dreadful fate of Tantalus, who": "11.582",
    "And I saw Sisyphus at his endless task raising": "11.593",
    "After him I saw mighty Hēraklēs, but it": "11.601",
    "Then Hēraklēs went down again into the house of": "11.627",
    "But when the ship left the stream of the": "12.1",
    "Then, when the child of morning, rosy-fingered Dawn, appeared": "12.8",
    "While we were doing all this, Circe, who": "12.16",
    "‘So far so good,’ said she, when I": "12.36",
    "Of these two rocks the one reaches the sky": "12.73",
    "You will find the other rocks lie lower, but": "12.101",
    "‘Is there no way,’ said I, ‘of escaping": "12.111",
    "‘You daring man,’ replied the goddess, ‘you are": "12.115",
    "You will now come to the Thrinacian island": "12.127",
    "Here she ended, and dawn enthroned in gold": "12.142",
    "Then, being much troubled in mind, I said to": "12.153",
    "I had hardly finished telling everything to the men": "12.165",
    "They sang these words most musically, and as I": "12.192",
    "Immediately after we had got past the island I": "12.201",
    "So they did as I told them; but I": "12.222",
    "Then we entered the Straits in great fear of": "12.234",
    "When we had passed the Wandering rocks, with Scylla": "12.260",
    "The men were in despair at this, and Eurylokhos": "12.277",
    "Thus spoke Eurylokhos, and the men approved his": "12.294",
    "As soon as they had had enough to eat": "12.308",
    "In the third watch of the night when the": "12.312",
    "For a whole month the wind blew steadily from": "12.324",
    "As long as wheat and wine held out the men did not touch the cattle": "12.327",
    "Thus spoke Eurylokhos, and the men approved his words": "12.352",
    "then, when the thigh bones were burned and they had tasted the innards, [365]": "12.364",
    "Meanwhile Lampetie of the light robes went straight off": "12.374",
    "‘Sun,’ said Zeus, ‘go on shining upon us": "12.384",
    "I was told all this by fair-haired Kalypsō": "12.389",
    "As soon as I got down to my ship": "12.391",
    "For six days my men kept driving in the": "12.397",
    "As soon as we were well away from the": "12.403",
    "Then Zeus let fly with his thunderbolts, and the": "12.415",
    "I stuck to the ship till the sea knocked": "12.420",
    "The gale from the West had now spent its": "12.426",
    "Hence I was carried along for nine days till": "12.447",
    
    # book 13

    "Thus did he speak, and they all held their peace throughout the covered hall": "13.1",
    "Alkinoos, the hallowed prince, went on board and saw everything": "13.13",
    "Thus did he speak. His hearers all of them approved his saying and agreed": "13.47",
    "And when the brightest of all stars began to show,": "13.93",
    "And Zeus answered, [140]": "13.139",
    "When the people heard this they were afraid and got ready the bulls": "13.184",
    "He counted his goodly coppers and cauldrons," : "13.217",
    "Resourceful great Odysseus was glad at finding himself, as Athena told him, in his own country,": "13.250",
    "Such was his story, but owl-vision Athena smiled and caressed him with her hand.": "13.287",
    "Then grey-eyed Athena said, [330] “You are always": "13.329",
    "Therewith she went down into the cave to look for the safest hiding places,": "13.366",
    "“But why,” said resourceful Odysseus, “did you not tell him, for you knew all about it?": "13.416",
    "There it was that I heard news of Odysseus, for the king told me he had entertained": "14.321",
    "[360] To this you answered, O swineherd Eumaios, “Poor unhappy stranger, I have found the story": "14.360",
"As he spoke he cut off the first piece and offered it as a burnt sacrifice": "14.446",
    "Then he raised his head on his elbow.": "14.494",
    
    "Odysseus now left the haven, and took the rough track ": "14.1",
    "He picked out two which he brought back with him and sacrificed": "14.48",
    "As he spoke he bound his belt round him and went to the sties": "14.72",
    "This was his story, but Odysseus went on eating and drinking [110]": "14.109",
    "Thus did he speak, and presently the swineherds came up with the pigs": "14.121",
    "“My friend,” replied long-suffering great Odysseus, “you are very positive, [150] ": "14.148",
    "And resourceful Odysseus answered, “I will tell you all about it. If there were meat": "14.191",
    "My house grew apace and I became a great man among the Cretans,": "14.235",
    "[285] I stayed there for seven years and got together much wealth among the Egyptians,": "14.285",
    
    '“And excellence [<foreign xml:lang="xgrc">aretē</foreign>] famed among men would be': "14.401",
    "But Athena went to the fair city of Lacedaemon": "15.1",
    "But Peisistratos, son of Nestor said, “No matter what": "15.48",
    "When Menelaos of the great war cry heard this he immediately told his wife": "15.92",
    "[130] So saying she gave the robe over": "15.130",
    "The spirited Telemachus repliece, [180]": "15.179",
    "But as Telemachus was thus busied, praying also and sacrificing to Athena": "15.222",
    "The spirited Telemachus said": "15.265",
    "Meanwhile Odysseus and the swineherd were eating their supper": "15.301",
    "[340] Much-enduring great Odysseus answered": "15.340",
    "[380] Resourceful Odysseus answered, “Then": "15.380",
    "[415] Now to this place there came": "15.415",
    "Then she went back to the house. [455]": "15.454",
    "Thus did they converse, and they had only a very little time left for sleep, [495]": "15.493",
    "[525] As he was speaking a bird flew by": "15.525",
# book 16
    "Meanwhile Odysseus and the noble swineherd had lit a fire": "16.1",
    "Odysseus went back to his own place, and Eumaios strewed some green": "16.46",
    "[90] Then long-suffering great Odysseus": "16.90",
    "[135] “I understand and heed you,”": "16.135",
    "So spoke Athena, and she touched him [= Odysseus] with her golden wand.": "16.172",
    "“As a different kind of person [": "16.181",
    '<seg rend="subscript">186</seg> And he' : "16.186",
    "He was answered by Odysseus, the one with many kinds of craft,": "16.201",
    "[225] “I will tell you the truth": "16.225",
    "“These two,” continued long-suffering great Odysseus, “will not keep": "16.266",
    "“Father,” replied Telemachus, “you will come to know me by and by, [310]": "16.308",
    "They left the river. The mules drew well and their hoofs went": "16.321",
    "He had hardly done speaking when Amphinomos turned in his place": "16.351",
    "They all held their peace until Amphinomos rose to speak.": "16.393",
    "To this Eurymakhos, son of Polybos, answered, [435] “Take heart,": "16.434",
    "When the child of morning, rosy-fingered Dawn, appeared, Telemachus,": "17.1",
    "“Do not scold me, mother,’ answered the spirited Telemachus,": "17.45",
    "With these words he took Theoklymenos to [85] his own house.": "17.84",
    "[120] Menelaos asked me": "17.120",
    "Thus did they converse. Meanwhile the suitors were throwing discs,": "17.166",
    "When they had got over the rough steep ground [205] and were nearing": "17.204",
    "Then Melanthios the goatherd answered, “You ill-conditioned cur" : "17.247",
    "[290] As they were thus talking" : "17.290",

    "Immediately afterwards Odysseus came inside, looking like a poor": "17.336",
    "Then Antinoos began to abuse the swineherd. [375] “You precious idiot,”": "17.374",
    "[380] And Eumaios answered, <seg": "17.380",
    "but it pleased Zeus, son of Kronos, to take all away from me. [425]": "17.424",
    "With these words he threw a footstool at him, and hit him": "17.462",
    "Thus did she talk with her maids as she sat in her own room,": "17.505",
    "“I will tell the daughter of Ikarios, circumspect Penelope,” answered": "17.560",
    "And there came a beggar, belonging to all the district": "18.1",
    "Resourceful Odysseus frowned on him and said, [15] “You daimonios!": "18.14",
    "The suitors all coming up laughing, and gathered round the": "18.36",
    "[50] The others all agreed,": "18.50",
    "This frightened Iros still more, but they brought him into": "18.88",
    "To this resourceful Odysseus answered, [125] “Amphinomos, you seem": "18.124",
    "Then the owl-vision goddess Athena put it into the mind": "18.158",
    "Eurynome answered, “[170] “My": "18.169",
    "With these words she came down from her upper room,": "18.206",
    "To this circumspect Penelope replied, “Eurymakhos, the gods robbed": "18.250",
    "The others applauded what Antinoos had said, and each one": "18.290",
    "“Maids, servants of Odysseus who has so long been absent,": "18.313",
    "“Vixen,” replied resourceful Odysseus, scowling at her, “I will go": "18.337",
    "“Eurymakhos,” answered resourceful Odysseus, “if you and I were to work": "18.365",
    "With this he caught hold of a footstool, but Odysseus": "18.394",

    # book 19

    "Great Odysseus was left in the hall, pondering on the": "19.1",
    "Telemachus approved of what his father had said, [15]": "19.14",
    "“The stranger,” said the spirited Telemachus, “shall show me": "19.26",
    "Then Telemachus went by torch-light to the other side of": "19.47",
    "Then circumspect Penelope came down from her room looking like": "19.53",
    "Circumspect Penelope heard what he was saying [90] and": "19.89",
    "“My lady,” answered resourceful Odysseus, “who among mortals": "19.107",
    "Then circumspect Penelope answered, “Stranger, the immortal gods robbed": "19.123",
    "This was what I said, and they assented;": "19.148",
    "Then resourceful Odysseus answered, [165] “My Lady, wife of": "19.164",
    "There’s a land called Crete, in the middle of": "19.172",
    "Right away he asked to see Idomeneus as soon": "19.190",
    "He made likenesses [eïskein], saying many deceptive [pseudea]": "19.203",
    "“My Lady,” answered resourceful Odysseus, “it is such a": "19.220",
    "I myself gave him a sword of bronze and": "19.241",
    "Penelope was moved still more deeply [250] as she": "19.249",
    "Then resourceful Odysseus answered, “My Lady, wife of Odysseus,": "19.261",
    "and they were all drowned to a man": "19.277",
    "“May it be even so,” answered circumspect Penelope; “if": "19.308",
    "And now, you maids, wash his feet for": "19.317",
    "if a man is harsh himself and thinks": "19.329",
    "Resourceful Odysseus answered, “My Lady, respected wife of Odysseus,": "19.335",
    "To this circumspect Penelope said, [350] “My dear": "19.349",
    "On these words the old woman covered her face with": "19.361",
    "“Son-in-law and daughter,” replied Autolykos, “call the child": "19.405",
    "[455] The sons of Autolykos busied themselves": "19.455",
    "“My child,” answered circumspect Eurykleia, “what are you": "19.491",
    "And resourceful Odysseus answered, [500] “Nurse, you ought not": "19.499",
    "Then circumspect Penelope began talking to him and said:": "19.508",
    "As when the daughter of Pandareos, the": "19.518",
    "“This dream, my Lady,” replied resourceful Odysseus, “can admit": "19.554",
    "Then he came back again, and perching on": "19.544",
    "And circumspect Penelope answered, [560] “Stranger, dreams are": "19.559",
    "I shall make the suitors try to perform the same feat": "19.576",
    "Then resourceful Odysseus answered, [582] “My Lady, wife of": "19.582",

    
    "Noble Odysseus slept in the hall upon an undressed": "20.1",
    "“Goddess,” answered resourceful Odysseus, “all that you have": "20.36",
    "The owl-vision goddess Athena replied, [45]": "20.44",
    "Then the day broke, but great Odysseus heard the": "20.91",
    "Circumspect Eurykleia said, [135]": "20.133",
    "Resourceful Odysseus made no answer, but bowed his head": "20.183",
    "“Stockman,” answered resourceful Odysseus, “you seem to be a": "20.226",
    "Telemachus, with craftiness [kerdos], made Odysseus sit in the": "20.257",
    "The suitors bit their lips, and marveled at the": "20.268",
    "As he spoke he picked up a heifer’s foot": "20.299",
    "[345] Athena now made the suitors" : "20.345",
    "The owl-vision goddess Athena now put it in daughter": "21.1",
    "Penelope presently reached the oak threshold of the store room;": "21.42",
    "“Listen to me you suitors, who persist in abusing": "21.68",
    "As she spoke, she told Eumaios the noble": "21.80",
    "Then the hallowed prince Telemachus spoke. “Skies above!”": "21.101",
    "As he spoke he sprang from his seat, threw": "21.118",
    "Then he put the bow down, letting it lean against the door, [165]": "21.163",
    "In like words Eumaios prayed to all the gods": "21.205",
    "At this moment the bow was in the hands of": "21.245",
    "“It shall not be so, Eurymakhos,” said Antinoos,": "21.256",
    "The rest approved his words, [270] and then men": "21.269",
    "Circumspect Penelope then spoke to him. “Antinoos,” said she,": "21.311",
    "“Eurymakhos,” circumspect Penelope answered, “people who persist in": "21.330",
    "Then the spirited Telemachus said, “Mother, I am the": "21.343",
    "She went wondering back into the house, [355] and": "21.354",
    "Another said, “I hope he may be no more": "21.401",

    #book 22
    "Then resourceful Odysseus tore off his rags, and sprang": "22.1",
    "They turned pale with fear as he spoke, and every man looked": "22.42",
    "As he spoke he drew his keen blade [80] of bronze,": "22.79",
    "Now there was a trap door on the wall, while at one end": "22.126",
    "[170] Resourceful Odysseus answered, “Telemachus and I will hold": "22.170",
    "But all the time he felt sure it was Athena, leader of armies,": "22.210",
    "They threw their spears as he bade them, but Athena made them": "22.255",
    "Thus spoke the stockman, and Odysseus struck the son of Damastor": "22.292",
    "[330] The minstrel Phemios, son of Terpes—he who had been forced": "22.330",
    "The pair went into the outer court as fast as they could,": "22.378",
    "[430] “Do not wake her yet,” answered resourceful Odysseus,": "22.430",
    "[465] So saying he made a ship’s cable fast to one": "22.465",
    "Eurykleia now went upstairs laughing to tell her mistress": "23.1",
    "But the corpses are now all piled up": "23.49",
    "[85] Then she came down from her upper room, and while doing so": "23.85",
    "Resourceful Odysseus answered, [130]": "23.129",
    "She said this to try him, but Odysseus was very angry": "23.181",
    "Then Odysseus in his turn melted, and wept as he clasped": "23.231",
    "“My dear,” answered resourceful Odysseus, “why should you press me": "23.263",
    "[310] He began with his victory over the Kikones, and how": "23.310",
    "Then the owl-vision goddess Athena thought of another matter.": "23.344",
    "Then Hermes of Cyllene summoned the spirits [psūkhai] of the suitors,": "24.1",
    "O you blessed [olbios] son of Peleus, godlike Achilles,": "24.35",
    "Your mother [Thetis] asked for and received from the gods very": "24.85",
    "And the spirit [psūkhē] of Amphimedon answered, “Agamemnon, son": "24.120",
    "‘Sweethearts,’ said she, ‘Great Odysseus is indeed" : "24.132",

    "This is what she said, and we assented; whereupon we could see her working upon her great web all day long, [140]": "24.138",
    "O blessed [olbios] son of Laertes, Odysseus of many wiles,": "24.191",
    "When much-enduring great Odysseus saw him so worn," : "24.232",

    "“Old sir,” said noble Odysseus, “it is clear that you": "24.244",
    "His father shed tears and answered, “Sir, you have indeed": "24.280",
    "“If you really are my son Odysseus,” replied Laertes," : "24.327",
    "“First observe this scar,” answered resourceful Odysseus, “which I": "24.330",
    "Then the old Sicilian woman took Laertes inside and washed him": "24.365",
    "While they were thus busy getting their dinner ready, Rumor": "24.412",
    "Then pale fear laid hold of them, and old Halitherses,": "24.450",
    "hey put on their armor as fast as they could—that ": "24.496",
}

# %%
import re
print(len(card_alignment))

basecards = {}
curchap = ''
curcard = ''
curbook = ''
curcit = ''
f = open('/Users/gcrane/github/canonical-greekLit/data/tlg0012/tlg002/tlg0012.tlg002.perseus-grc2.xml')
for l in f:

    m = re.search('n="([^"]+)"[^>]+book"',l)
    if(m):
        curbook = m[1] + '.'
        #print('curbook',curbook)
    m = re.search('<milestone[^>]+n="([^"]+)[^>]+unit="card"',l)
    if(m):
        curcit = curbook + m[1]
        basecards[curcit] = 1

    m = re.search('type="chapter"[^>]+n="([^"]+)',l)
    if(m):
        curchap = m[1] + '.'
    m = re.search('type="subchapter"[^>]+n="([^"]+)',l)
    if(m):
        curcard = curbook + curchap +  m[1]
        basecards[curcard] = 1

newcards = {}

def additem(curdict,curitem):
    if(curitem in curdict):
        curdict[curitem] = curdict[curitem] + 1
    else:
        curdict[curitem] = 1
        

for foo in card_alignment:
    additem(newcards,str(card_alignment[foo]))

for foo in newcards:
    if(newcards[foo] > 1):
        print('extra1',foo,newcards[foo])
   # if(not str(foo) in basecards):
   #     print('extra2',foo)

i = 0
for foo in basecards:
    continue
    if(not foo in newcards):
        print('missing',foo)
    else:
        i = i + 1
        #print(i,'confirmed',foo)
# Out:
# 417

# %%
import re


f = open("/Users/gcrane/gitlab/tei.xml-files/teifiles/Homeric-Odyssey-Butler-trans/Homeric-Odyssey.tei.xml")



workbuf = f.read()
workbuf = re.sub('\n([a-zA-Z\[>“‘])',' \g<1>',workbuf)

# workbuf = re.sub('<milestone unit="card"[^>]+>',' ',workbuf)
missed = 0
i = 0
for foo in card_alignment:
    if(not str(card_alignment[foo]) in basecards):
       # print('skipping',foo,card_alignment[foo])
        continue
    curkey = foo
    curkey2 = ''
    n = workbuf.count(curkey)
    #print('test',n,foo,card_alignment[foo])
    if(not n == 1):
        curkey = foo[0:20]
        #print(n,card_alignment[foo],foo,'shorthit20',curkey)

    
        n = workbuf.count(curkey)
    if(not n == 1):
        curkey = foo[0:10]
        #print('shorthit',curkey)
        n = workbuf.count(curkey)
    if(not n == 1):
        
        print(missed,n,'>'+foo+'<',card_alignment[foo],'[['+curkey+']]')
        missed = missed + 1
        continue
    i = i + 1
    #print(i,'adding',card_alignment[foo],foo)
    curmile = '<milestone unit="card" n="'+str(card_alignment[foo])+'"/>'
    workbuf = re.sub('(<milestone unit="card"[^>]+>)\s*(\[[0-9]+\])','\g<2>\g<1>',workbuf)
    workbuf = workbuf.replace(curkey,curmile+curkey)

f.close()
outfname = '../staging/tlg0012.tlg002.butlernagy2020-eng2.xml'
outf = open(outfname,'w')
outf.write(workbuf)
outf.close()

n = workbuf.count('"card"')
print('cards',n,'should be',len(basecards))
# Out:
# cards 288 should be 288

# %%
savebuf = workbuf

addedcards = []
while( re.search('<milestone unit="card" n="([^"]+)',workbuf)):
    m = re.search('<milestone unit="card" n="([^"]+)',workbuf)
    addedcards.append(m[1])
    workbuf = re.sub('<milestone unit="card" n="([^"]+)','',workbuf,1)

for foo in basecards:
    if(not foo in addedcards):
        print('missing',foo)

# %%
workbuf1 = re.sub('(\[[0-9]+|<div)','<ZZ>\g<1>', savebuf)

n = workbuf1.count('unit="card"')
print('cards',n,'should be',len(basecards))
i = 0
curbook = "1"
curline = "1"
cardbook = "1"
for foo in workbuf1.split('<ZZ>'):
    i = i + 1
    m = re.search('"book" n="([0-9]+)"',foo)
    if(m):
        curbook = m[1]
        cardbook = curbook
        curcard = curbook + '.1'
        curline = '1'

    m = re.search('^\[([0-9]+)',foo)
    if(m):
        curline = m[1]
    m = re.search('unit="card" n="([^"]+)"',foo)
    if(m):
        curcard = m[1]
    if(re.search('(unit="card"|"book")',foo) and curcard):
        #print('card',curcard,foo)
        cardbook,cardline = curcard.split('.')
        if(not cardbook == curbook):
            print('\nbookfail',curbook,cardbook,curline,curcard,foo)
        cardlnum = int(cardline)
        curlnum = int(curline)
        if(cardlnum < curlnum):
            print('\ntooearly',curline,curcard,foo)
        if(cardlnum > curlnum + 5):
            print('\ntoolate',curline,curcard,foo)
# Out:
# cards 288 should be 288
