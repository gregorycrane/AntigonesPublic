# %%
note2bekker = {
    "lemma_note1": "1.1",
    "lemma_note2": "1.4",
    "lemma_note3": "1.5",
    "lemma_1": "1.6",
    "lemma_5": "1.7",
    "lemma_6": "1.8",
    "lemma_7": "1.10",
    "lemma_8": "1.11",
    "lemma_9": "1.11",
    "lemma_10": "1.12",
    "lemma_11": "1.12",
    "lemma_12": "2.2",
    "lemma_13": "2.4",
    "lemma_14": "2.5",
    "lemma_15": "2.5",
    "lemma_16": "2.5",
    "lemma_17": "2.6",
    "lemma_18": "3.2",
    "lemma_19": "3.4",
    "lemma_20": "3.5",
    "lemma_21": "4.3",
    "lemma_22": "4.4",
    "lemma_23": "4.4",
    "lemma_24": "4.6",
    "lemma_25": "4.7",
    "lemma_26": "4.7",
    "lemma_27": "4.10",
    "lemma_28": "4.12",
    "lemma_29": "4.14",
    "lemma_30": "4.16",
    "lemma_31": "4.16",
    "lemma_32": "4.16",
    "lemma_33": "4.17",
    "lemma_34": "4.18",
    "lemma_35": "4.19",
    "lemma_36": "4.19",
    "lemma_37": "4.20",
    "lemma_38": "5.1",
    "lemma_41": "5.5",
    "lemma_43": "5.9",
    "lemma_44": "6.2",
    "lemma_45": "6.2",
    "lemma_46": "6.4",
    "lemma_47": "6.6",
    "lemma_48": "6.8",
    "lemma_49": "6.11",
    "lemma_50": "6.12",
    "lemma_79": "9.11c",
    "lemma_80": "9.12",
    "lemma_81": "10.1",
    "lemma_82": "10.2",
    "lemma_83": "11.1",
    "lemma_96": "13.5",
    "lemma_39": "5.4",
    "lemma_40": "5.4",
    "lemma_42": "5.7",
    "lemma_51": "6.15",
    "lemma_52": "6.15",
    "lemma_53": "6.16",
    "lemma_54": "6.18",
    "lemma_55": "6.22",
    "lemma_56": "6.22",
    "lemma_57": "6.23",
    "lemma_58": "6.24",
    "lemma_59": "7.4",
    "lemma_60": "7.8",
    "lemma_61": "7.8",
    "lemma_62": "7.9",
    "lemma_63": "7.9",
    "lemma_64": "7.11",
    "lemma_65": "8.1",
    "lemma_66": "8.3",
    "lemma_67": "8.3",
    "lemma_68": "8.4",
    "lemma_69": "9.1",
    "lemma_70": "9.2",
    "lemma_71": "9.3",
    "lemma_72": "9.5",
    "lemma_73": "9.6",
    "lemma_74": "9.9",
    "lemma_75": "9.10",
    "lemma_76": "9.11",
    "lemma_77": "9.11b",
    "lemma_78": "9.11b",
    "lemma_84": "11.2",
    "lemma_85": "11.9",
    "lemma_86": "11.10",
    "lemma_87": "11.10",
    "lemma_88": "12.3",
    "lemma_89": "12.5",
    "lemma_90": "12.7",
    "lemma_91": "12.8",
    "lemma_92": "12.9",
    "lemma_93": "13.2",
    "lemma_94": "13.3",
    "lemma_95": "13.4",
    "lemma_97": "13.10",
    "lemma_98": "13.10",
    "lemma_99": "13.11",
    "lemma_100": "13.13",
    "lemma_101": "14.4",
    "lemma_102": "14.6",
    "lemma_103": "14.9",
    "lemma_104": "14.11",
    "lemma_105": "14.15",
    "lemma_106": "14.19",
    "lemma_107": "14.19",
    "lemma_108": "15.2",
    "lemma_109": "15.3",
    "lemma_110": "15.5",
    "lemma_111": "15.6",
    "lemma_112": "15.7",
    "lemma_113": "15.9",
    "lemma_114": "15.10b",
    "lemma_115": "15.10b",
    "lemma_116": "15.10c",
    "lemma_117": "15.11",
    "lemma_118": "15.11",
    "lemma_119": "15.11",
    "lemma_120": "15.12",

    "lemma_121": "16.5",
    "lemma_122": "16.5",
    "lemma_123": "16.6",
    "lemma_124": "16.6",
    "lemma_125": "16.6",
    "lemma_126": "16.6",
    "lemma_127": "16.7",
    "lemma_128": "16.8",
    "lemma_129": "16.8",
    "lemma_130": "16.9",
    "lemma_131": "16.9",
    "lemma_132": "16.10",
    "lemma_133": "16.11",
    "lemma_134": "16.11",
    "lemma_135": "17.2",
    "lemma_136": "17.3",
    "lemma_137": "17.3",
    "lemma_138": "17.3",
    "lemma_139": "17.4",
    "lemma_140": "17.4",
    "lemma_141": "17.5",
    "lemma_142": "17.7",
    "lemma_143": "17.8",
    "lemma_144": "17.9",
    "lemma_145": "17.10",
    "lemma_146": "17.10",
    "lemma_147": "17.10",
    "lemma_148": "18.2",
    "lemma_149": "18.3",
    "lemma_150": "18.4",
    "lemma_151": "18.7",
    "lemma_152": "18.8",
    "lemma_153": "18.14",
    "lemma_154": "18.15",
    "lemma_155": "18.16",
    "lemma_156": "18.18",
    "lemma_157": "18.19",
    "lemma_158": "18.20",
    "lemma_159": "19.5",
    "lemma_160": "19.5",
    "lemma_161": "19.6",
    "lemma_162": "19.6",
    "lemma_163": "19.7",
    "lemma_164": "19.7",
    "lemma_165": "19.8",
    "lemma_166": "20.1",
    "lemma_167": "20.1",
    "lemma_168": "20.4",
    "lemma_169": "20.4",
    "lemma_170": "20.6",
    "lemma_171": "20.7",
    "lemma_172": "20.8",
    "lemma_173": "20.9",
    "lemma_174": "20.10",
    "lemma_175": "20.12",
    "lemma_176": "20.12",
    "lemma_177": "20.13",
    "lemma_178": "21.3",
    "lemma_179": "21.5",
    "lemma_180": "21.6",
    "lemma_181": "21.9",
    "lemma_182": "21.10",
    "lemma_183": "21.11",
    "lemma_184": "21.12",
    "lemma_185": "21.12",
    "lemma_186": "21.13",
    "lemma_187": "21.14",
    "lemma_188": "21.14",
    "lemma_189": "21.16",
    "lemma_190": "21.17",
    "lemma_191": "21.21",
    "lemma_192": "22.1",
    "lemma_193": "22.2",
    "lemma_194": "22.2",
    "lemma_195": "22.4",
    "lemma_196": "22.5",
    "lemma_197": "22.5",
    "lemma_198": "22.5",
    "lemma_199": "22.9",
    "lemma_200": "22.9",
    "lemma_201": "22.10",
    "lemma_202": "22.12",
    "lemma_203": "22.12",
    "lemma_204": "22.13",
    "lemma_205": "22.13",
    "lemma_206": "22.13",
    "lemma_207": "22.17",
    "lemma_208": "22.18",
    "lemma_209": "22.19",

    "lemma_210": "23.4",
    "lemma_211": "23.4",
    "lemma_212": "23.6",
    "lemma_213": "23.6",
    "lemma_214": "24.3",
    "lemma_215": "24.5",
    "lemma_216": "24.9",
    "lemma_223": "24.21",
    "lemma_224": "24.22",
    "lemma_225": "24.23",
    "lemma_226": "24.23",
    "lemma_227": "24.23",
    "lemma_228": "25.3",
    "lemma_229": "25.3",
    "lemma_230": "25.4",
    "lemma_217": "24.11",
    "lemma_218": "24.11",
    "lemma_219": "24.14",
    "lemma_220": "24.15",
    "lemma_221": "24.16",
    "lemma_222": "24.18",
    "lemma_238": "25.13",
    "lemma_239": "25.14",
    "lemma_240": "25.16",
    "lemma_241": "25.16",
    "lemma_231": "25.5",
    "lemma_232": "25.6",
    "lemma_233": "25.7",
    "lemma_234": "25.8",
    "lemma_235": "25.10",
    "lemma_236": "25.11",
    "lemma_237": "25.11",
    "lemma_242": "25.17",
    "lemma_243": "25.17",
    "lemma_244": "25.18",
    "lemma_245": "25.18",
    "lemma_246": "25.19",
    "lemma_247": "25.20",
    "lemma_248": "25.21",
    "lemma_249": "25.21",
    "lemma_250": "25.22",
    "lemma_251": "25.23",
    "lemma_252": "25.24",
    "lemma_253": "25.25",
    "lemma_254": "25.28",
    "lemma_255": "25.29",
    "lemma_256": "25.30",
    "lemma_257": "25.30",
    "lemma_258": "25.31",
    "lemma_259": "25.32",
    "lemma_260": "25.32",
    "lemma_261": "25.32",
    "lemma_262": "25.32",
    "lemma_263": "26.2",
    "lemma_264": "26.3",
    "lemma_270": "26.7",
    "lemma_271": "26.10",
    "lemma_272": "26.11",
    "lemma_273": "26.12",
    "lemma_274": "26.13",
    "lemma_275": "26.13",
    "lemma_276": "26.13",
    "lemma_277": "26.15",
    "lemma_265": "26.6",
    "lemma_266": "26.6",
    "lemma_267": "26.10",
    "lemma_268": "26.11",
    "lemma_269": "26.13",


    
}

# %%
import re

fname = '/Users/gcrane/github/Poetics2.0/eng/twining.poetics-commentary.xml'

outfname = '/Users/gcrane/github/AntigonesPublic/staging/tlg0086.tlg034.twining1789-commentary-eng2.xml'

f = open(fname)

sawids = []
outf = open(outfname,'w')
for l in f:
    m = re.search('<mentioned ana="#([^"]+)',l)
    if(m):
        curid = m[1]
        if(not curid in note2bekker):
            print(curid,'not in dict',l)
        else:
            sawids.append(curid)
            curbekker = '<milestone unit="bekker" n="'+note2bekker[curid]+'"/>'
            l = re.sub('(<mentioned)',curbekker + '\g<1>',l)
    print (l,end='',file=outf)

f.close()
outf.close()

for foo in note2bekker:
    if( not foo in sawids):
        print('missed',foo)

# %%
note2bekker
# Out:
# {'lemma_note1': '1.1',
#  'lemma_note2': '1.4',
#  'lemma_note3': '1.5',
#  'lemma_1': '1.6',
#  'lemma_5': '1.7',
#  'lemma_6': '1.8',
#  'lemma_7': '1.10',
#  'lemma_8': '1.11',
#  'lemma_9': '1.11',
#  'lemma_10': '1.12',
#  'lemma_11': '1.12',
#  'lemma_12': '2.2',
#  'lemma_13': '2.4',
#  'lemma_14': '2.5',
#  'lemma_15': '2.5',
#  'lemma_16': '2.5',
#  'lemma_17': '2.6',
#  'lemma_18': '3.2',
#  'lemma_19': '3.4',
#  'lemma_20': '3.5',
#  'lemma_21': '4.3',
#  'lemma_22': '4.4',
#  'lemma_23': '4.4',
#  'lemma_24': '4.6',
#  'lemma_25': '4.7',
#  'lemma_26': '4.7',
#  'lemma_27': '4.10',
#  'lemma_28': '4.12',
#  'lemma_29': '4.14',
#  'lemma_30': '4.16',
#  'lemma_31': '4.16',
#  'lemma_32': '4.16',
#  'lemma_33': '4.17',
#  'lemma_34': '4.18',
#  'lemma_35': '4.19',
#  'lemma_36': '4.19',
#  'lemma_37': '4.20',
#  'lemma_38': '5.1',
#  'lemma_41': '5.5',
#  'lemma_43': '5.9',
#  'lemma_44': '6.2',
#  'lemma_45': '6.2',
#  'lemma_46': '6.4',
#  'lemma_47': '6.6',
# ...
